# %% [markdown]
# # PANDAS ALTERNATIVES IN PYTHON
#
# - System:
#
#     Mackbook Pro 15 Inch, 2019
#
#         Processor: 2.3 GHz 8-Core Intel Core i9
#
#         Memory: 16 GB 2400 MHz DDR4
#
#         macOS:  Sonoma 14.5 Beta (23F5049f)
#
# - Python 3.12.2
#
# ______

# %%
#Importing libraries 
import polars as pl
import datatable  as dt
import os
os.environ['MODIN_ENGINE'] = 'dask'
import modin.pandas as md
import modin
print("NUM Partitions available: ", modin.config.NPartitions.get())
import pandas as pd
import time
import numpy as np
from statistics import mean, stdev
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>
# NUM Partitions available:  16

# %%
def exec_time(code_str):
    start = time.time()
    exec(code_str)
    end = time.time()
    return np.round((end-start)/60*1000, 6)

def functiontiming(cmd_d, metr_nm, dictionary, loop = 10, add_cmd = None):
    print(metr_nm)
    for key, cmd in cmd_d.items():
        counter = 0
        times = []
        try: 
            while counter <= loop:
                if add_cmd:
                    new_cmd = add_cmd[key]
                    exec_time(new_cmd)
                time = exec_time(cmd)
                times.append(time)
                counter +=1
            meant = np.round(mean(times), 6)
            stdevt = np.round(stdev(times), 6)
            maxt = np.round(max(times), 6)
            mint = np.round(min(times), 6)
            add_dic = {'METRIC': metr_nm, 'LIBRARY': key, 'TIME (avg)': meant, "TIME (stdv)": stdevt, "TIME (max)": maxt, "TIME (min)": mint,   'N': loop}

        except Exception as E:
            print(key, " ERROR:\n", str(E))
            add_dic = {}
        add_dic = {'METRIC': metr_nm, 'LIBRARY': key, 'TIME (avg)': meant, "TIME (stdv)": stdevt, "TIME (max)": maxt, "TIME (min)": mint,   'N': loop}
        if metr_nm in dictionary:
            dictionary[metr_nm].append(add_dic)
        else: 
            dictionary[metr_nm] = [add_dic]
        print(key, '\t', meant, 'usec')     

def dict_to_df(dictionary, file_size = None):
    df = pd.DataFrame()
    for k, v in dictionary.items(): 
        df1 = pd.DataFrame(v)
        df = pd.concat([df, df1], axis = 0).reset_index(drop = True)
    if file_size: 
        df.loc[:,'FILE_SZ'] = file_size
    return df

# %% [markdown]
# ______
# ### ~SMALL FILE

# %%
# Number of data points to calculate statictics 
loops = 5
file = 'data/data_small.csv'
print("File size: ", np.round(os.stat(file).st_size / (1024 * 1024), 2), "MB")
RESULT_SM = {}
# Out:
# File size:  13.84 MB

# %%
cmdsrd = {
        'datatable': 'global dtdf ; dtdf = dt.fread(file)',
        'pandas'   : 'global pdf  ; pdf = pd.read_csv(file, low_memory = False )',
        'polars'   : 'global pldf ; pldf = pl.read_csv(file, infer_schema_length=100000, ignore_errors = True )',
        'modin'    : 'global mdf  ; mdf = md.read_csv(file, low_memory = False)'
        }
metric = 'READ_CSV'
functiontiming(cmdsrd, metric, RESULT_SM, loop = loops)
# Out:
# READ_CSV
# datatable 	 2.11185 usec
# pandas 	 10.170699 usec
# polars 	 8.450216 usec
# UserWarning: `read_*` implementation has mismatches with pandas:
# Data types of partitions are different! Please refer to the troubleshooting section of the Modin documentation to fix this issue.
# modin 	 31.46889 usec

# %%
cmdshp = {
        'datatable': 'dtdf.shape',
        'pandas'   : 'pdf.shape',
        'polars'   : 'pldf.shape',
        'modin'    : 'mdf.shape'
        }
metric = 'PRINT DF SHAPE'

functiontiming(cmdshp, metric, RESULT_SM, loop = loops)
# Out:
# PRINT DF SHAPE
# datatable 	 0.000576 usec
# pandas 	 0.00057 usec
# polars 	 0.002391 usec
# modin 	 0.027424 usec

# %%
cmds_copy = {
        'datatable': 'global dtdf1 ; dtdf1 = dtdf.copy()',
         'pandas'  : 'global pdf1  ; pdf1 = pdf.copy()',
         'polars'  : 'global pldf1 ; pldf1 = pldf.clone()',
         'modin'   : 'global mdf1  ; mdf1 = mdf.copy()'
        }
metric = 'CREATE COPY'
functiontiming(cmds_copy, metric, RESULT_SM, loop = loops)
# Out:
# CREATE COPY
# datatable 	 0.001021 usec
# pandas 	 0.305885 usec
# polars 	 0.001061 usec
# modin 	 0.014641 usec

# %%
cmds_col1 = {
         'datatable': 'global dtdf1 ; dtdf1.names = {"CRASH_CRN":"CRASH_CRNnew"}',
         'pandas'   : 'global pdf1  ; pdf1 = pdf1.rename(columns = {"CRASH_CRN":"CRASH_CRNnew"})',
         'polars'   : 'global pldf1 ; pldf1 = pldf1.rename({"CRASH_CRN":"CRASH_CRNnew"})',
         'modin'    : 'global mdf1  ; mdf1 = mdf1.rename(columns = {"CRASH_CRN":"CRASH_CRNnew"})'
        }
metric = 'RENAME SINGLE COLUMN'
functiontiming(cmds_col1, metric, RESULT_SM, add_cmd = cmds_copy, loop = loops)
# Out:
# RENAME SINGLE COLUMN
# datatable 	 0.005223 usec
# pandas 	 0.227212 usec
# polars 	 0.045403 usec
# modin 	 0.172026 usec

# %%
new_columns = [col+'NEW' for col in pdf.columns]
new_colums_dict = {}
for col in pdf.columns:
    new_colums_dict[col] = col+'NEW'

cmds_col_all = {
         'datatable': 'global dtdf  ; dtdf.names = new_columns',
         'pandas'   : 'global pdf   ; pdf.columns = new_columns',
         # For polars to work with no errors I had to create a new dataframe. 
         # Tests without new copy in other platforms worked with no issues
         'polars'   : 'global pldf2 ; pldf2 =  pldf.rename(new_colums_dict)',
         'modin'    : 'global mdf   ; mdf = mdf.rename(columns = new_colums_dict)'
        }
metric = 'RENAME ALL COLUMNS'
functiontiming(cmds_col_all, metric, RESULT_SM, add_cmd = cmds_copy, loop = loops)
# Out:
# RENAME ALL COLUMNS
# datatable 	 0.001378 usec
# pandas 	 0.005412 usec
# polars 	 0.031144 usec
# modin 	 0.190545 usec

# %%
cmds_sort1 = {
         'datatable': 'dtdf[:,:, dt.sort("MUNICIPALITYNEW", reverse=True)]',
         'pandas'   : 'pdf.sort_values(by = ["MUNICIPALITYNEW"], ascending = [False])',
         'polars'   : 'pldf2.sort("MUNICIPALITYNEW", descending=True)',
         'modin'    : 'mdf.sort_values(by = ["MUNICIPALITYNEW"], ascending = [False])'
        }
metric = 'SORT ONE COLUMN'
functiontiming(cmds_sort1, metric, RESULT_SM, loop = loops)
# Out:
# SORT ONE COLUMN
# datatable 	 0.029972 usec
# pandas 	 0.361782 usec
# polars 	 0.356631 usec
# modin 	 21.721003 usec

# %%
cmds_sort2 = {
         'datatable': 'dtdf[:,:, dt.sort(["MUNICIPALITYNEW", "CRASH_YEARNEW"], reverse=[True, False])]',
         'pandas'   : 'pdf.sort_values(by = ["MUNICIPALITYNEW", "CRASH_YEARNEW"], ascending = [False, True])',
         'polars'   : 'pldf2.sort("MUNICIPALITYNEW", "CRASH_YEARNEW", descending=[True, False])',
         'modin'    : 'mdf.sort_values(by = ["MUNICIPALITYNEW", "CRASH_YEARNEW"], ascending = [False, True])'
        }
metric = 'SORT TWO COLUMN'
functiontiming(cmds_sort2, metric, RESULT_SM, loop = loops)
# Out:
# SORT TWO COLUMN
# datatable 	 0.094605 usec
# pandas 	 0.435026 usec
# polars 	 0.282675 usec
# modin 	 16.357789 usec

# %%
from datatable import dt, f, by
grp_by_sum = {
         'datatable': 'dtdf[:, dt.sum(f.CRASH_YEARNEW), by("MUNICIPALITYNEW")]',
         'pandas'   : 'pdf.groupby("MUNICIPALITYNEW")["CRASH_YEARNEW"].sum()',
         'polars'   : 'pldf2.group_by("MUNICIPALITYNEW").agg(pl.sum("CRASH_YEARNEW"))',
         'modin'    : 'mdf.groupby("MUNICIPALITYNEW")["CRASH_YEARNEW"].sum()'
        }
metric = 'GROUP BY SUM'
functiontiming(grp_by_sum, metric, RESULT_SM, loop = loops)
# Out:
# GROUP BY SUM
# datatable 	 0.026237 usec
# pandas 	 0.080098 usec
# polars 	 0.840643 usec
# modin 	 12.694547 usec

# %%
dict_to_df(RESULT_SM, 'Small')
# Out:
#                   METRIC    LIBRARY  TIME (avg)  TIME (stdv)  TIME (max)  \
# 0               READ_CSV  datatable    2.111850     0.117092    2.348399
# 1               READ_CSV     pandas   10.170699     0.898767   11.888186
# 2               READ_CSV     polars    8.450216     1.261416   10.907936
# 3               READ_CSV      modin   31.468890    39.065252  111.138916
# 4         PRINT DF SHAPE  datatable    0.000576     0.000203    0.000970
# 5         PRINT DF SHAPE     pandas    0.000570     0.000150    0.000866
# 6         PRINT DF SHAPE     polars    0.002391     0.004495    0.011563
# 7         PRINT DF SHAPE      modin    0.027424     0.064834    0.159764
# 8            CREATE COPY  datatable    0.001021     0.000531    0.002086
# 9            CREATE COPY     pandas    0.305885     0.193735    0.568072
# 10           CREATE COPY     polars    0.001061     0.000679    0.002432
# 11           CREATE COPY      modin    0.014641     0.002036    0.017881
# 12  RENAME SINGLE COLUMN  datatable    0.005223     0.005108    0.015616
# 13  RENAME SINGLE COLUMN     pandas    0.227212     0.065078    0.358216
# 14  RENAME SINGLE COLUMN     polars    0.045403     0.104263    0.258219
# 15  RENAME SINGLE COLUMN      modin    0.172026     0.027525    0.226684
# 16    RENAME ALL COLUMNS  datatable    0.001378     0.000335    0.002054
# 17    RENAME ALL COLUMNS     pandas    0.005412     0.000833    0.006533
# 18    RENAME ALL COLUMNS     polars    0.031144     0.018435    0.061131
# 19    RENAME ALL COLUMNS      modin    0.190545     0.060797    0.311450
# 20       SORT ONE COLUMN  datatable    0.029972     0.036443    0.104249
# 21       SORT ONE COLUMN     pandas    0.361782     0.068657    0.496980
# 22       SORT ONE COLUMN     polars    0.356631     0.267831    0.892484
# 23       SORT ONE COLUMN      modin   21.721003     8.452766   37.705771
# 24       SORT TWO COLUMN  datatable    0.094605     0.037178    0.154134
# 25       SORT TWO COLUMN     pandas    0.435026     0.126420    0.673433
# 26       SORT TWO COLUMN     polars    0.282675     0.062866    0.394619
# 27       SORT TWO COLUMN      modin   16.357789     4.330814   20.023696
# 28          GROUP BY SUM  datatable    0.026237     0.019036    0.065053
# 29          GROUP BY SUM     pandas    0.080098     0.067881    0.206530
# 30          GROUP BY SUM     polars    0.840643     0.529117    1.584868
# 31          GROUP BY SUM      modin   12.694547     2.067477   16.778568
#
#     TIME (min)  N FILE_SZ
# 0     2.044749  5   Small
# 1     9.481529  5   Small
# 2     7.547748  5   Small
# 3    13.636220  5   Small
# 4     0.000449  5   Small
# 5     0.000481  5   Small
# 6     0.000465  5   Small
# 7     0.000763  5   Small
# 8     0.000715  5   Small
# 9     0.165097  5   Small
# 10    0.000683  5   Small
# 11    0.012767  5   Small
# 12    0.002635  5   Small
# 13    0.180912  5   Small
# 14    0.002038  5   Small
# 15    0.152699  5   Small
# 16    0.001180  5   Small
# 17    0.004152  5   Small
# 18    0.017297  5   Small
# 19    0.150498  5   Small
# 20    0.011865  5   Small
# 21    0.310886  5   Small
# 22    0.200601  5   Small
# 23   13.196651  5   Small
# 24    0.063801  5   Small
# 25    0.313648  5   Small
# 26    0.227018  5   Small
# 27    7.911273  5   Small
# 28    0.017532  5   Small
# 29    0.024068  5   Small
# 30    0.325584  5   Small
# 31   11.324048  5   Small

# %% [markdown]
# _____
#
# ### ~Medium file

# %%
### Deleting dataframes used with the Small file data
del dtdf, dtdf1, pdf, pdf1, pldf, pldf1, pldf2, mdf, mdf1

# %%
file = 'data/data_medium.csv'
print("File size: ", np.round(os.stat(file).st_size / (1024 * 1024), 2), "MB")
RESULT_MD = {}
# Out:
# File size:  140.68 MB

# %%
metric = 'READ_CSV'
functiontiming(cmdsrd, metric, RESULT_MD, loop = loops)
metric = 'PRINT DF SHAPE'
functiontiming(cmdshp, metric, RESULT_MD, loop = loops)
metric = 'CREATE COPY'
functiontiming(cmds_copy, metric, RESULT_MD, loop = loops)
metric = 'RENAME SINGLE COLUMN'
functiontiming(cmds_col1, metric, RESULT_MD, add_cmd = cmds_copy, loop = loops)
metric = 'RENAME ALL COLUMNS'
functiontiming(cmds_col_all, metric, RESULT_MD, add_cmd = cmds_copy, loop = loops)
metric = 'SORT ONE COLUMN'
functiontiming(cmds_sort1, metric, RESULT_MD, loop = loops)
metric = 'SORT TWO COLUMN'
functiontiming(cmds_sort2, metric, RESULT_MD, loop = loops)
metric = 'GROUP BY SUM'
functiontiming(grp_by_sum, metric, RESULT_MD, loop = loops)
# Out:
# READ_CSV
# datatable 	 8.495389 usec
# pandas 	 133.949207 usec
# polars 	 42.378396 usec
# modin 	 50.545182 usec
# PRINT DF SHAPE
# datatable 	 0.000555 usec
# pandas 	 0.000546 usec
# polars 	 0.000542 usec
# modin 	 0.273244 usec
# CREATE COPY
# datatable 	 0.000994 usec
# pandas 	 5.630147 usec
# polars 	 0.000997 usec
# modin 	 0.019892 usec
# RENAME SINGLE COLUMN
# datatable 	 0.001465 usec
# pandas 	 4.538616 usec
# polars 	 0.005574 usec
# modin 	 0.177732 usec
# RENAME ALL COLUMNS
# datatable 	 0.001293 usec
# pandas 	 0.004352 usec
# polars 	 0.020648 usec
# modin 	 0.214852 usec
# SORT ONE COLUMN
# datatable 	 0.028874 usec
# pandas 	 6.34738 usec
# polars 	 3.633539 usec
# modin 	 35.488041 usec
# SORT TWO COLUMN
# datatable 	 0.248273 usec
# pandas 	 9.517631 usec
# polars 	 3.111469 usec
# modin 	 31.740092 usec
# GROUP BY SUM
# datatable 	 0.130297 usec
# pandas 	 0.316852 usec
# polars 	 1.400083 usec
# modin 	 39.141619 usec

# %%
dict_to_df(RESULT_MD, 'Medium')
# Out:
#                   METRIC    LIBRARY  TIME (avg)  TIME (stdv)  TIME (max)  \
# 0               READ_CSV  datatable    8.495389     1.192051   10.380983
# 1               READ_CSV     pandas  133.949207     5.208238  142.682370
# 2               READ_CSV     polars   42.378396     7.739363   56.540100
# 3               READ_CSV      modin   50.545182    13.134925   76.994185
# 4         PRINT DF SHAPE  datatable    0.000555     0.000189    0.000930
# 5         PRINT DF SHAPE     pandas    0.000546     0.000130    0.000803
# 6         PRINT DF SHAPE     polars    0.000542     0.000169    0.000882
# 7         PRINT DF SHAPE      modin    0.273244     0.666467    1.633664
# 8            CREATE COPY  datatable    0.000994     0.000354    0.001697
# 9            CREATE COPY     pandas    5.630147     2.666759   11.005580
# 10           CREATE COPY     polars    0.000997     0.000457    0.001899
# 11           CREATE COPY      modin    0.019892     0.011840    0.041918
# 12  RENAME SINGLE COLUMN  datatable    0.001465     0.000163    0.001784
# 13  RENAME SINGLE COLUMN     pandas    4.538616     0.340780    5.220083
# 14  RENAME SINGLE COLUMN     polars    0.005574     0.004986    0.014468
# 15  RENAME SINGLE COLUMN      modin    0.177732     0.012044    0.197597
# 16    RENAME ALL COLUMNS  datatable    0.001293     0.000167    0.001617
# 17    RENAME ALL COLUMNS     pandas    0.004352     0.000633    0.005432
# 18    RENAME ALL COLUMNS     polars    0.020648     0.011033    0.035302
# 19    RENAME ALL COLUMNS      modin    0.214852     0.063446    0.295866
# 20       SORT ONE COLUMN  datatable    0.028874     0.015411    0.060050
# 21       SORT ONE COLUMN     pandas    6.347380     0.107086    6.499883
# 22       SORT ONE COLUMN     polars    3.633539     1.855839    7.416681
# 23       SORT ONE COLUMN      modin   35.488041    16.541908   67.893378
# 24       SORT TWO COLUMN  datatable    0.248273     0.029982    0.289949
# 25       SORT TWO COLUMN     pandas    9.517631     6.423335   22.449938
# 26       SORT TWO COLUMN     polars    3.111469     0.146062    3.295549
# 27       SORT TWO COLUMN      modin   31.740092    14.190822   48.853866
# 28          GROUP BY SUM  datatable    0.130297     0.055282    0.206900
# 29          GROUP BY SUM     pandas    0.316852     0.116053    0.498819
# 30          GROUP BY SUM     polars    1.400083     0.173685    1.608098
# 31          GROUP BY SUM      modin   39.141619    16.134830   62.317701
#
#     TIME (min)  N FILE_SZ
# 0     7.481853  5  Medium
# 1   128.757719  5  Medium
# 2    36.833914  5  Medium
# 3    43.215716  5  Medium
# 4     0.000433  5  Medium
# 5     0.000453  5  Medium
# 6     0.000449  5  Medium
# 7     0.000834  5  Medium
# 8     0.000767  5  Medium
# 9     4.145881  5  Medium
# 10    0.000699  5  Medium
# 11    0.012616  5  Medium
# 12    0.001347  5  Medium
# 13    4.305013  5  Medium
# 14    0.002003  5  Medium
# 15    0.165367  5  Medium
# 16    0.001172  5  Medium
# 17    0.003811  5  Medium
# 18    0.011281  5  Medium
# 19    0.155834  5  Medium
# 20    0.020337  5  Medium
# 21    6.217035  5  Medium
# 22    2.789736  5  Medium
# 23   20.884252  5  Medium
# 24    0.212185  5  Medium
# 25    6.054934  5  Medium
# 26    2.938068  5  Medium
# 27    9.990295  5  Medium
# 28    0.082481  5  Medium
# 29    0.160988  5  Medium
# 30    1.156767  5  Medium
# 31   25.571016  5  Medium

# %% [markdown]
# _____
#
# ### ~Large file

# %%
### Deleting dataframes used with the Medium file data
del dtdf, dtdf1, pdf, pdf1, pldf, pldf1, pldf2, mdf, mdf1

# %%
file = 'data/data_large.csv'
print("File size: ", np.round(os.stat(file).st_size / (1024 * 1024), 2), "MB")
RESULT_LG = {}
# Out:
# File size:  281.36 MB

# %%
metric = 'READ_CSV'
functiontiming(cmdsrd, metric, RESULT_LG, loop = loops)
metric = 'PRINT DF SHAPE'
functiontiming(cmdshp, metric, RESULT_LG, loop = loops)
metric = 'CREATE COPY'
functiontiming(cmds_copy, metric, RESULT_LG, loop = loops)
metric = 'RENAME SINGLE COLUMN'
functiontiming(cmds_col1, metric, RESULT_LG, add_cmd = cmds_copy, loop = loops)
metric = 'RENAME ALL COLUMNS'
functiontiming(cmds_col_all, metric, RESULT_LG, add_cmd = cmds_copy, loop = loops)
metric = 'SORT ONE COLUMN'
functiontiming(cmds_sort1, metric, RESULT_LG, loop = loops)
metric = 'SORT TWO COLUMN'
functiontiming(cmds_sort2, metric, RESULT_LG, loop = loops)
metric = 'GROUP BY SUM'
functiontiming(grp_by_sum, metric, RESULT_LG, loop = loops)
# Out:
# READ_CSV
# datatable 	 12.570404 usec
# pandas 	 263.400897 usec
# polars 	 44.289981 usec

# %%
dict_to_df(RESULT_LG, 'Large')
# Out:
#                   METRIC    LIBRARY  TIME (avg)  TIME (stdv)  TIME (max)  \
# 0               READ_CSV  datatable   13.227933     1.259448   15.076586
# 1               READ_CSV     pandas  275.883256    10.966589  294.587771
# 2               READ_CSV     polars   45.740524     2.415947   50.384919
# 3               READ_CSV      modin   87.811360     8.920497  103.634683
# 4         PRINT DF SHAPE  datatable    0.000870     0.000320    0.001486
# 5         PRINT DF SHAPE     pandas    0.000845     0.000210    0.001252
# 6         PRINT DF SHAPE     polars    0.000772     0.000404    0.001530
# 7         PRINT DF SHAPE      modin    0.255906     0.624544    1.530751
# 8            CREATE COPY  datatable    0.001058     0.000593    0.002249
# 9            CREATE COPY     pandas   11.767563     4.745111   21.441380
# 10           CREATE COPY     polars    0.001136     0.000807    0.002766
# 11           CREATE COPY      modin    0.017008     0.004700    0.022852
# 12  RENAME SINGLE COLUMN  datatable    0.001501     0.000148    0.001705
# 13  RENAME SINGLE COLUMN     pandas   10.779182     0.798559   12.353484
# 14  RENAME SINGLE COLUMN     polars    0.009550     0.013256    0.036248
# 15  RENAME SINGLE COLUMN      modin    0.181790     0.018276    0.207949
# 16    RENAME ALL COLUMNS  datatable    0.001494     0.000330    0.002102
# 17    RENAME ALL COLUMNS     pandas    0.003945     0.000083    0.004049
# 18    RENAME ALL COLUMNS     polars    0.031440     0.035454    0.101439
# 19    RENAME ALL COLUMNS      modin    0.188477     0.051976    0.260047
# 20       SORT ONE COLUMN  datatable    0.090380     0.137994    0.368214
# 21       SORT ONE COLUMN     pandas   14.783140     0.410566   15.554365
# 22       SORT ONE COLUMN     polars   10.217147     4.894814   20.134334
# 23       SORT ONE COLUMN      modin   40.136794    27.782713   95.542685
# 24       SORT TWO COLUMN  datatable    0.316293     0.166312    0.646996
# 25       SORT TWO COLUMN     pandas   21.134816    15.819275   53.394651
# 26       SORT TWO COLUMN     polars    8.204487     1.528342   11.305002
# 27       SORT TWO COLUMN      modin   23.341476     9.495171   38.043495
# 28          GROUP BY SUM  datatable    0.143444     0.019119    0.171856
# 29          GROUP BY SUM     pandas    0.321226     0.157671    0.564861
# 30          GROUP BY SUM     polars    3.010077     0.791393    4.192185
# 31          GROUP BY SUM      modin   15.499125     4.686612   24.531305
#
#     TIME (min)  N FILE_SZ
# 0    11.836366  5   Large
# 1   262.724300  5   Large
# 2    43.631780  5   Large
# 3    79.810981  5   Large
# 4     0.000620  5   Large
# 5     0.000703  5   Large
# 6     0.000481  5   Large
# 7     0.000751  5   Large
# 8     0.000727  5   Large
# 9     9.660049  5   Large
# 10    0.000699  5   Large
# 11    0.012465  5   Large
# 12    0.001351  5   Large
# 13   10.268585  5   Large
# 14    0.002432  5   Large
# 15    0.153037  5   Large
# 16    0.001232  5   Large
# 17    0.003799  5   Large
# 18    0.011452  5   Large
# 19    0.148118  5   Large
# 20    0.020754  5   Large
# 21   14.505680  5   Large
# 22    7.199132  5   Large
# 23   22.099519  5   Large
# 24    0.214648  5   Large
# 25   13.901214  5   Large
# 26    7.479481  5   Large
# 27    8.322235  5   Large
# 28    0.123084  5   Large
# 29    0.198948  5   Large
# 30    2.115369  5   Large
# 31   12.330262  5   Large

# %% [markdown]
# ____
#
# # Combining the results

# %%
results = dict_to_df(RESULT_LG).drop(['N'], axis = 1).merge(dict_to_df(RESULT_MD), on = ['METRIC', 'LIBRARY'], suffixes=['_LG', '_MD']).drop(['N'], axis = 1).merge(dict_to_df(RESULT_SM), on = ['METRIC', 'LIBRARY'])
ordered_columns = ['METRIC', 'LIBRARY', 'TIME (avg)_LG', 'TIME (avg)_MD', 'TIME (avg)',
                    'TIME (stdv)_LG', 'TIME (stdv)_MD', 'TIME (stdv)', 
                    'TIME (max)_LG', 'TIME (max)_MD', 'TIME (max)',
                    'TIME (min)_LG', 'TIME (min)_MD', 'TIME (min)', 'N']
results[ordered_columns]
# Out:
#                   METRIC    LIBRARY  TIME (avg)_LG  TIME (avg)_MD  TIME (avg)  \
# 0               READ_CSV  datatable      13.227933       8.088036    2.256663
# 1               READ_CSV     pandas     275.883256     131.175152    9.567757
# 2               READ_CSV     polars      45.740524      37.420094    7.579748
# 3               READ_CSV      modin      87.811360      42.186915   30.116153
# 4         PRINT DF SHAPE  datatable       0.000870       0.001134    0.000516
# 5         PRINT DF SHAPE     pandas       0.000845       0.001069    0.000613
# 6         PRINT DF SHAPE     polars       0.000772       0.000592    0.000769
# 7         PRINT DF SHAPE      modin       0.255906       0.098544    0.073182
# 8            CREATE COPY  datatable       0.001058       0.000862    0.002473
# 9            CREATE COPY     pandas      11.767563       4.567713    0.376607
# 10           CREATE COPY     polars       0.001136       0.001386    0.001189
# 11           CREATE COPY      modin       0.017008       0.014384    0.017542
# 12  RENAME SINGLE COLUMN  datatable       0.001501       0.001491    0.001704
# 13  RENAME SINGLE COLUMN     pandas      10.779182       3.834852    0.235305
# 14  RENAME SINGLE COLUMN     polars       0.009550       0.014848    0.021652
# 15  RENAME SINGLE COLUMN      modin       0.181790       0.165949    0.234559
# 16    RENAME ALL COLUMNS  datatable       0.001494       0.001285    0.001358
# 17    RENAME ALL COLUMNS     pandas       0.003945       0.004094    0.003992
# 18    RENAME ALL COLUMNS     polars       0.031440       0.032170    0.020800
# 19    RENAME ALL COLUMNS      modin       0.188477       0.187504    0.233963
# 20       SORT ONE COLUMN  datatable       0.090380       0.023354    0.015481
# 21       SORT ONE COLUMN     pandas      14.783140       5.766939    0.357378
# 22       SORT ONE COLUMN     polars      10.217147       3.460634    0.309233
# 23       SORT ONE COLUMN      modin      40.136794      24.026629   22.934677
# 24       SORT TWO COLUMN  datatable       0.316293       0.192103    0.070919
# 25       SORT TWO COLUMN     pandas      21.134816       8.158210    0.703754
# 26       SORT TWO COLUMN     polars       8.204487       3.039420    0.340531
# 27       SORT TWO COLUMN      modin      23.341476      25.841174   25.404165
# 28          GROUP BY SUM  datatable       0.143444       0.073506    0.016400
# 29          GROUP BY SUM     pandas       0.321226       0.235467    0.064039
# 30          GROUP BY SUM     polars       3.010077       1.582403    0.141986
# 31          GROUP BY SUM      modin      15.499125      18.043927   15.224070
#
#     TIME (stdv)_LG  TIME (stdv)_MD  TIME (stdv)  TIME (max)_LG  TIME (max)_MD  \
# 0         1.259448        0.571234     0.281275      15.076586       8.986684
# 1        10.966589        7.433915     1.731816     294.587771     143.873111
# 2         2.415947        2.762096     0.778228      50.384919      41.197546
# 3         8.920497        4.257195    34.289706     103.634683      50.791419
# 4         0.000320        0.000303     0.000144       0.001486       0.001470
# 5         0.000210        0.000330     0.000239       0.001252       0.001649
# 6         0.000404        0.000243     0.000504       0.001530       0.001053
# 7         0.624544        0.239088     0.175793       1.530751       0.586581
# 8         0.000593        0.000197     0.000990       0.002249       0.001236
# 9         4.745111        1.459028     0.210295      21.441380       7.392168
# 10        0.000807        0.001450     0.000880       0.002766       0.004335
# 11        0.004700        0.003700     0.006592       0.022852       0.021831
# 12        0.000148        0.000163     0.000330       0.001705       0.001800
# 13        0.798559        0.063166     0.034566      12.353484       3.924151
# 14        0.013256        0.027858     0.023165       0.036248       0.071482
# 15        0.018276        0.020796     0.039851       0.207949       0.207913
# 16        0.000330        0.000156     0.000300       0.002102       0.001585
# 17        0.000083        0.000578     0.000177       0.004049       0.005269
# 18        0.035454        0.039433     0.013310       0.101439       0.111349
# 19        0.051976        0.054504     0.082403       0.260047       0.284020
# 20        0.137994        0.009595     0.007736       0.368214       0.041318
# 21        0.410566        0.102947     0.033303      15.554365       5.908000
# 22        4.894814        1.361584     0.092187      20.134334       6.218421
# 23       27.782713        9.089202     7.676803      95.542685      39.636266
# 24        0.166312        0.017328     0.015285       0.646996       0.218411
# 25       15.819275        5.007821     0.156034      53.394651      18.175153
# 26        1.528342        0.037562     0.044102      11.305002       3.085430
# 27        9.495171       14.911577     5.286304      38.043495      49.079633
# 28        0.019119        0.011489     0.005163       0.171856       0.088088
# 29        0.157671        0.172918     0.022889       0.564861       0.559421
# 30        0.791393        0.485997     0.021807       4.192185       2.544848
# 31        4.686612       10.899403     4.779771      24.531305      39.629900
#
#     TIME (max)  TIME (min)_LG  TIME (min)_MD  TIME (min)  N
# 0     2.809799      11.836366       7.421585    2.045202  5
# 1    12.859452     262.724300     124.596918    8.171618  5
# 2     9.160948      43.631780      35.529733    7.188614  5
# 3    99.933183      79.810981      39.709802   14.208885  5
# 4     0.000787       0.000620       0.000652    0.000417  5
# 5     0.001085       0.000703       0.000751    0.000469  5
# 6     0.001752       0.000481       0.000429    0.000449  5
# 7     0.432018       0.000751       0.000783    0.001164  5
# 8     0.004033       0.000727       0.000719    0.001550  5
# 9     0.689050       9.660049       3.705883    0.220450  5
# 10    0.002964       0.000699       0.000683    0.000731  5
# 11    0.030645       0.012465       0.012449    0.013030  5
# 12    0.002333       0.001351       0.001363    0.001347  5
# 13    0.281552      10.268585       3.778454    0.197752  5
# 14    0.057932       0.002432       0.002118    0.002285  5
# 15    0.300781       0.153037       0.154650    0.180634  5
# 16    0.001959       0.001232       0.001184    0.001168  5
# 17    0.004248       0.003799       0.003747    0.003751  5
# 18    0.045768       0.011452       0.012100    0.011539  5
# 19    0.360747       0.148118       0.148884    0.156633  5
# 20    0.030402       0.020754       0.017015    0.010566  5
# 21    0.409929      14.505680       5.661531    0.326498  5
# 22    0.474866       7.199132       2.784121    0.218570  5
# 23   34.499915      22.099519      14.831018   13.823164  5
# 24    0.093166       0.214648       0.177519    0.054379  5
# 25    0.992084      13.901214       5.543884    0.578884  5
# 26    0.390251       7.479481       2.987234    0.283897  5
# 27   33.304497       8.322235       7.881347   19.835448  5
# 28    0.026735       0.123084       0.060316    0.013268  5
# 29    0.105282       0.198948       0.125086    0.045482  5
# 30    0.163118       2.115369       1.223481    0.115418  5
# 31   24.178449      12.330262      11.512601   11.507968  5
