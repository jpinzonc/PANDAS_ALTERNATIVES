# %% [markdown]
# # PANDAS ALTERNATIVES IN PYTHON
#
# - System:
#
#     Mackbook Pro 15 Inch, 2019
#
#         Processor: 2.3 GHz 8-Core Intel Core i9
#
#         Memory: 16 GB 2400 MHz DDR4
#
#         macOS:  Sonoma 14.5 Beta (23F5049f)
#
# - Python 3.10.9
#
# ______

# %%
# Importing libraries 
import polars as pl
import datatable  as dt
import os
os.environ['MODIN_ENGINE'] = 'dask'
import modin.pandas as md
import modin
print("NUM Partitions available: ", modin.config.NPartitions.get())
# os.environ["MODIN_CPUS"] = "4"
import pandas as pd
import time
import numpy as np
from statistics import mean, stdev
import vaex as vx

# Initializing dask 
# from distributed import Client
# client = Client() 
from dask.distributed import Client
client = Client()
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>
# NUM Partitions available:  16
# UserWarning:
# Dask needs bokeh >= 2.4.2, < 3 for the dashboard.
# You have bokeh==3.0.3.
# Continuing without the dashboard.

# %%
def exec_time(code_str):
    start = time.time()
    exec(code_str, globals(), locals())
    end = time.time()
    return np.round((end-start)/60*1000, 6)

def functiontiming(cmd_d, metr_nm, dictionary, loop = 10, add_cmd = None):
    print(metr_nm)
    for key, cmd in cmd_d.items():
        counter = 0
        times = []
        try: 
            while counter <= loop:
                if add_cmd:
                    new_cmd = add_cmd[key]
                    exec_time(new_cmd)
                time = exec_time(cmd)
                times.append(time)
                counter +=1
            meant = np.round(mean(times), 6)
            stdevt = np.round(stdev(times), 6)
            maxt = np.round(max(times), 6)
            mint = np.round(min(times), 6)
            add_dic = {'METRIC': metr_nm, 'LIBRARY': key, 'TIME (avg)': meant, "TIME (stdv)": stdevt, "TIME (max)": maxt, "TIME (min)": mint,   'N': loop}

        except Exception as E:
            print(key, " ERROR:\n", str(E))
            add_dic = {}

        if metr_nm in dictionary:
            dictionary[metr_nm].append(add_dic)
        else: 
            dictionary[metr_nm] = [add_dic]
        try: 
            print(key, '\t', meant, 'usec')     
        except: print('No data')
        
def dict_to_df(dictionary, file_size = None):
    df = pd.DataFrame()
    for k, v in dictionary.items(): 
        df1 = pd.DataFrame(v)
        df = pd.concat([df, df1], axis = 0).reset_index(drop = True)
    if file_size: 
        df.loc[:,'FILE_SZ'] = file_size
    return df

# %% [markdown]
# ______
# ### ~SMALL FILE

# %%
# Number of data points to calculate statictics 
loops = 5
file = 'data/data_small.csv'
savedir = 'data_save'
savefile = f'{savedir}/results.csv'
print("File size: ", np.round(os.stat(file).st_size / (1024 * 1024), 2), "MB")
RESULT_SM = {}
# Out:
# File size:  28.92 MB

# %%
cmdsrd = {
        'datatable': 'global dtdf ; dtdf = dt.fread(file)',
        'pandas'   : 'global pdf  ; pdf  = pd.read_csv(file, low_memory = False )',
        'polars'   : 'global pldf ; pldf = pl.read_csv(file, infer_schema_length=100000, ignore_errors = True )',
        'modin'    : 'global mdf  ; mdf  = md.read_csv(file, low_memory = False)',
        'vaex'     : 'global vxdf ; vxdf = vx.open(file)'
        }
metric = 'READ_CSV'
functiontiming(cmdsrd, metric, RESULT_SM, loop = loops)
# Out:
# READ_CSV
# datatable 	 3.940627 usec
# pandas 	 25.351358 usec
# polars 	 16.157204 usec
# modin 	 39.581374 usec
# vaex 	 11.292836 usec

# %%
import os
import shutil
os.mkdir(savedir)
sv_cmd = {'datatable':'dtdf.to_csv(savefile)', 
          'pandas'   : 'pdf.to_csv(savefile)',
          'polars'   : 'pldf.write_csv(savefile)',
          'modin'    : 'mdf.to_csv(savefile)',
          'vaex'     : 'vxdf.export_csv(savefile)'
          }
metric = 'SAVE_CSV'
functiontiming(sv_cmd, metric, RESULT_SM, loop = loops)
shutil.rmtree(savedir)
# Out:
# SAVE_CSV
# datatable 	 0.984232 usec
# pandas 	 72.855192 usec
# polars 	 1.62887 usec
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# Please refer to https://modin.readthedocs.io/en/stable/supported_apis/defaulting_to_pandas.html for explanation.
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# modin 	 87.246204 usec
# vaex 	 534.885055 usec

# %%
cmdshp = {
        'datatable': 'dtdf.shape',
        'pandas'   : 'pdf.shape',
        'polars'   : 'pldf.shape',
        'modin'    : 'mdf.shape',
        'vaex'     : 'vxdf.shape'
        }
metric = 'PRINT DF SHAPE'

functiontiming(cmdshp, metric, RESULT_SM, loop = loops)
# Out:
# PRINT DF SHAPE
# datatable 	 0.000414 usec
# pandas 	 0.000388 usec
# polars 	 0.000411 usec
# modin 	 0.000516 usec
# vaex 	 0.001003 usec

# %%
cmds_copy = {
         'datatable': 'global dtdf1 ; dtdf1 = dtdf.copy()',
         'pandas'  : 'global pdf1  ; pdf1 = pdf.copy()',
         'polars'  : 'global pldf1 ; pldf1 = pldf.clone()',
         'modin'   : 'global mdf1  ; mdf1 = mdf.copy()',
         'vaex'    : 'global vxdf1 ; vxdf1 = vxdf.copy()'
        }
metric = 'CREATE COPY'
functiontiming(cmds_copy, metric, RESULT_SM, loop = loops)
# Out:
# CREATE COPY
# datatable 	 0.000673 usec
# pandas 	 0.579664 usec
# polars 	 0.00075 usec
# modin 	 0.003819 usec
# vaex 	 0.065703 usec

# %%
cmds_col1 = {
         'datatable': 'global dtdf1 ; dtdf1.names = {"CRASH_CRN":"CRASH_CRNnew"}',
         'pandas'   : 'global pdf1  ; pdf1 = pdf1.rename(columns = {"CRASH_CRN":"CRASH_CRNnew"})',
         'polars'   : 'global pldf1 ; pldf1 = pldf1.rename({"CRASH_CRN":"CRASH_CRNnew"})',
         'modin'    : 'global mdf1  ; mdf1 = mdf1.rename(columns = {"CRASH_CRN":"CRASH_CRNnew"})',
         'vaex'     :  'vxdf1.rename("CRASH_CRN","CRASH_CRNnew")'
        }
metric = 'RENAME SINGLE COLUMN'
functiontiming(cmds_col1, metric, RESULT_SM, add_cmd = cmds_copy, loop = loops)
# Out:
# RENAME SINGLE COLUMN
# datatable 	 0.001292 usec
# pandas 	 0.427207 usec
# polars 	 0.002967 usec
# modin 	 0.06453 usec
# vaex 	 0.072675 usec

# %%
new_columns = [col+'NEW' for col in pdf.columns]
new_colums_dict = {}
for col in pdf.columns:
    new_colums_dict[col] = col+'NEW'

cmds_col_all = {
         'datatable': 'global dtdf  ; dtdf.names = new_columns',
         'pandas'   : 'global pdf   ; pdf.columns = new_columns',
         # For polars to work with no errors I had to create a new dataframe. 
         # Tests without new copy in other platforms worked with no issues
         'polars'   : 'global pldf2 ; pldf2 =  pldf.rename(new_colums_dict)',
         'modin'    : 'global mdf   ; mdf = mdf.rename(columns = new_colums_dict)',
         'vaex'     : 'for cur_nm, new_nm in new_colums_dict.items(): vxdf1.rename(cur_nm, new_nm)'
        }
metric = 'RENAME ALL COLUMNS'
functiontiming(cmds_col_all, metric, RESULT_SM, add_cmd = cmds_copy, loop = loops)
# Out:
# RENAME ALL COLUMNS
# datatable 	 0.001176 usec
# pandas 	 0.007341 usec
# polars 	 0.018073 usec
# modin 	 0.067706 usec
# vaex 	 4.531886 usec

# %%
cmds_sort1 = {
         'datatable': 'dtdf[:,:, dt.sort("MUNICIPALITYNEW", reverse=True)]',
         'pandas'   : 'pdf.sort_values(by = ["MUNICIPALITYNEW"], ascending = [False])',
         'polars'   : 'pldf2.sort("MUNICIPALITYNEW", descending=True)',
         'modin'    : 'mdf.sort_values(by = ["MUNICIPALITYNEW"], ascending = [False])',
         'vaex'     : 'vxdf.sort(["MUNICIPALITY"])'
        }
metric = 'SORT ONE COLUMN'
functiontiming(cmds_sort1, metric, RESULT_SM, loop = loops)
# Out:
# SORT ONE COLUMN
# datatable 	 0.014867 usec
# pandas 	 0.858475 usec
# polars 	 0.628156 usec
# modin 	 17.596347 usec
# vaex 	 2.896077 usec

# %%
cmds_sort2 = {
         'datatable': 'dtdf[:,:, dt.sort(["MUNICIPALITYNEW", "CRASH_YEARNEW"], reverse=[True, False])]',
         'pandas'   : 'pdf.sort_values(by = ["MUNICIPALITYNEW", "CRASH_YEARNEW"], ascending = [False, True])',
         'polars'   : 'pldf2.sort("MUNICIPALITYNEW", "CRASH_YEARNEW", descending=[True, False])',
         'modin'    : 'mdf.sort_values(by = ["MUNICIPALITYNEW", "CRASH_YEARNEW"], ascending = [False, True])',
         'vaex'     : 'vxdf.sort(["MUNICIPALITY", "CRASH_YEAR"], ascending = [False, True])'
        }
metric = 'SORT TWO COLUMN'
functiontiming(cmds_sort2, metric, RESULT_SM, loop = loops)
# Out:
# SORT TWO COLUMN
# datatable 	 0.072828 usec
# pandas 	 0.845255 usec
# polars 	 0.467051 usec
# modin 	 17.933064 usec
# vaex 	 5.320963 usec

# %%
from datatable import dt, f, by
grp_by_sum = {
         'datatable': 'dtdf[:, dt.sum(f.CRASH_YEARNEW), by("MUNICIPALITYNEW")]',
         'pandas'   : 'pdf.groupby("MUNICIPALITYNEW")["CRASH_YEARNEW"].sum()',
         'polars'   : 'pldf2.group_by("MUNICIPALITYNEW").agg(pl.sum("CRASH_YEARNEW"))',
         'modin'    : 'mdf.groupby("MUNICIPALITYNEW")["CRASH_YEARNEW"].sum()',
         'vaex'     : "vxdf.groupby(by='MUNICIPALITY').agg({'CRASH_YEAR': 'sum'})"

        }
metric = 'GROUP BY SUM'
functiontiming(grp_by_sum, metric, RESULT_SM, loop = loops)
# Out:
# GROUP BY SUM
# datatable 	 0.020727 usec
# pandas 	 0.033396 usec
# polars 	 0.213065 usec
# modin 	 3.655963 usec
# vaex 	 10.301689 usec

# %%
dict_to_df(RESULT_SM, 'Small')
# Out:
#                   METRIC    LIBRARY  TIME (avg)  TIME (stdv)  TIME (max)  \
# 0               READ_CSV  datatable    3.940627     1.066808    6.060481
# 1               READ_CSV     pandas   25.351358     0.686571   26.546466
# 2               READ_CSV     polars   16.157204     2.573165   21.246596
# 3               READ_CSV      modin   39.581374    68.146814  178.671499
# 4               READ_CSV       vaex   11.292836    16.592047   45.156582
# 5               SAVE_CSV  datatable    0.984232     0.140555    1.189033
# 6               SAVE_CSV     pandas   72.855192     1.136612   74.613603
# 7               SAVE_CSV     polars    1.628870     0.570921    2.510802
# 8               SAVE_CSV      modin   87.246204     7.689869  100.682231
# 9               SAVE_CSV       vaex  534.885055    12.795306  552.846917
# 10        PRINT DF SHAPE  datatable    0.000414     0.000166    0.000735
# 11        PRINT DF SHAPE     pandas    0.000388     0.000139    0.000668
# 12        PRINT DF SHAPE     polars    0.000411     0.000168    0.000751
# 13        PRINT DF SHAPE      modin    0.000516     0.000157    0.000834
# 14        PRINT DF SHAPE       vaex    0.001003     0.000133    0.001268
# 15           CREATE COPY  datatable    0.000673     0.000210    0.001065
# 16           CREATE COPY     pandas    0.579664     0.319171    1.127434
# 17           CREATE COPY     polars    0.000750     0.000368    0.001482
# 18           CREATE COPY      modin    0.003819     0.000966    0.005770
# 19           CREATE COPY       vaex    0.065703     0.007468    0.073834
# 20  RENAME SINGLE COLUMN  datatable    0.001292     0.000329    0.001951
# 21  RENAME SINGLE COLUMN     pandas    0.427207     0.015372    0.456834
# 22  RENAME SINGLE COLUMN     polars    0.002967     0.002735    0.008535
# 23  RENAME SINGLE COLUMN      modin    0.064530     0.008368    0.078233
# 24  RENAME SINGLE COLUMN       vaex    0.072675     0.008699    0.088469
# 25    RENAME ALL COLUMNS  datatable    0.001176     0.000188    0.001498
# 26    RENAME ALL COLUMNS     pandas    0.007341     0.001477    0.009004
# 27    RENAME ALL COLUMNS     polars    0.018073     0.007724    0.030001
# 28    RENAME ALL COLUMNS      modin    0.067706     0.014806    0.090265
# 29    RENAME ALL COLUMNS       vaex    4.531886     0.092871    4.688418
# 30       SORT ONE COLUMN  datatable    0.014867     0.005638    0.026298
# 31       SORT ONE COLUMN     pandas    0.858475     0.198916    1.224848
# 32       SORT ONE COLUMN     polars    0.628156     0.425498    1.488268
# 33       SORT ONE COLUMN      modin   17.596347     3.783573   23.409466
# 34       SORT ONE COLUMN       vaex    2.896077     0.699699    4.063805
# 35       SORT TWO COLUMN  datatable    0.072828     0.004279    0.079131
# 36       SORT TWO COLUMN     pandas    0.845255     0.317449    1.486516
# 37       SORT TWO COLUMN     polars    0.467051     0.034101    0.517567
# 38       SORT TWO COLUMN      modin   17.933064     2.395777   21.845349
# 39       SORT TWO COLUMN       vaex    5.320963     0.490288    5.887246
# 40          GROUP BY SUM  datatable    0.020727     0.003338    0.026850
# 41          GROUP BY SUM     pandas    0.033396     0.015517    0.063864
# 42          GROUP BY SUM     polars    0.213065     0.014388    0.229251
# 43          GROUP BY SUM      modin    3.655963     0.187266    4.021736
# 44          GROUP BY SUM       vaex   10.301689     1.360323   12.711052
#
#     TIME (min)  N FILE_SZ
# 0     3.218969  5   Small
# 1    24.818301  5   Small
# 2    14.663553  5   Small
# 3    10.731900  5   Small
# 4     4.080784  5   Small
# 5     0.807826  5   Small
# 6    71.627132  5   Small
# 7     1.065652  5   Small
# 8    81.026268  5   Small
# 9   517.595367  5   Small
# 10    0.000298  5   Small
# 11    0.000314  5   Small
# 12    0.000330  5   Small
# 13    0.000433  5   Small
# 14    0.000918  5   Small
# 15    0.000517  5   Small
# 16    0.289599  5   Small
# 17    0.000532  5   Small
# 18    0.003298  5   Small
# 19    0.053902  5   Small
# 20    0.001101  5   Small
# 21    0.413116  5   Small
# 22    0.001669  5   Small
# 23    0.053362  5   Small
# 24    0.064584  5   Small
# 25    0.001001  5   Small
# 26    0.005619  5   Small
# 27    0.010669  5   Small
# 28    0.055635  5   Small
# 29    4.455066  5   Small
# 30    0.011496  5   Small
# 31    0.687738  5   Small
# 32    0.381335  5   Small
# 33   14.550662  5   Small
# 34    2.083862  5   Small
# 35    0.066467  5   Small
# 36    0.685684  5   Small
# 37    0.421087  5   Small
# 38   14.873000  5   Small
# 39    4.713869  5   Small
# 40    0.018104  5   Small
# 41    0.022284  5   Small
# 42    0.191116  5   Small
# 43    3.500267  5   Small
# 44    9.015266  5   Small

# %% [markdown]
# _____
#
# ### ~Medium file

# %%
### Deleting dataframes used with the Small file data
del dtdf, dtdf1, pdf, pdf1, pldf, pldf1, pldf2, mdf, mdf1, vxdf, vxdf1

# %%
file = 'data/data_medium.csv'
print("File size: ", np.round(os.stat(file).st_size / (1024 * 1024), 2), "MB")
RESULT_MD = {}
# Out:
# File size:  145.88 MB

# %%
metric = 'READ_CSV'
functiontiming(cmdsrd, metric, RESULT_MD, loop = loops)
os.mkdir(savedir)
metric = 'SAVE_CSV'
functiontiming(sv_cmd, metric, RESULT_MD, loop = loops)
shutil.rmtree(savedir)
metric = 'PRINT DF SHAPE'
functiontiming(cmdshp, metric, RESULT_MD, loop = loops)
metric = 'CREATE COPY'
functiontiming(cmds_copy, metric, RESULT_MD, loop = loops)
metric = 'RENAME SINGLE COLUMN'
functiontiming(cmds_col1, metric, RESULT_MD, add_cmd = cmds_copy, loop = loops)
metric = 'RENAME ALL COLUMNS'
functiontiming(cmds_col_all, metric, RESULT_MD, add_cmd = cmds_copy, loop = loops)
metric = 'SORT ONE COLUMN'
functiontiming(cmds_sort1, metric, RESULT_MD, loop = loops)
metric = 'SORT TWO COLUMN'
functiontiming(cmds_sort2, metric, RESULT_MD, loop = loops)
metric = 'GROUP BY SUM'
functiontiming(grp_by_sum, metric, RESULT_MD, loop = loops)
# Out:
# READ_CSV
# datatable 	 9.150714 usec
# pandas 	 140.943228 usec
# polars 	 37.758227 usec
# UserWarning: `read_*` implementation has mismatches with pandas:
# Data types of partitions are different! Please refer to the troubleshooting section of the Modin documentation to fix this issue.
# modin 	 49.846721 usec
# vaex 	 5.508926 usec
# SAVE_CSV
# datatable 	 5.152349 usec
# pandas 	 397.776264 usec
# polars 	 7.406933 usec
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# modin 	 443.226678 usec
# vaex  ERROR:
#  Error reading csv file data/data_medium.csv, write offending chunk to: /var/folders/dg/fckc2gz96c599j8pqfzz6jzr0000gn/T/tmpjofryni_.csv (len=10486076, first=False, columns=['SCHOOL_BUS_UNIT'], schema=SCHOOL_BUS_UNIT: int8, encoding=utf8, schema_infer_fraction=0.001).
# Possible causes:
#   * This could be a file encoding error. Consider passing read_options=pyarrow.csv.ReadOptions(encoding="ISO-8859-1") or another encoding as argument.
#   * We might have inferred the wrong schema:
#      * Consider giving a schema hint by e.g. passing read_options=pyarrow.csv.ConvertOptions(column_types={"SomeId": pyarrow.string()}).
#      * Consider increasing schema_infer_fraction (e.g. schema_infer_fraction=1 to parse the whole file to infer the schema).
#
# vaex 	 443.226678 usec
# PRINT DF SHAPE
# datatable 	 0.000633 usec
# pandas 	 0.000485 usec
# polars 	 0.000876 usec
# modin 	 0.000584 usec
# vaex 	 0.00145 usec
# CREATE COPY
# datatable 	 0.001081 usec
# pandas 	 5.320282 usec
# polars 	 0.00133 usec
# modin 	 0.005005 usec
# vaex 	 0.07148 usec
# RENAME SINGLE COLUMN
# datatable 	 0.001455 usec
# pandas 	 4.335425 usec
# polars 	 0.00701 usec
# modin 	 0.062653 usec
# vaex 	 0.075974 usec
# RENAME ALL COLUMNS
# datatable 	 0.001971 usec
# pandas 	 0.005689 usec
# polars 	 0.026182 usec
# modin 	 0.064195 usec
# vaex 	 4.565752 usec
# SORT ONE COLUMN
# datatable 	 0.032224 usec
# pandas 	 6.196677 usec
# polars 	 5.518208 usec
# modin 	 48.791028 usec
# vaex 	 10.279816 usec
# SORT TWO COLUMN
# datatable 	 0.177851 usec
# pandas 	 7.902062 usec
# polars 	 3.752621 usec
# modin 	 43.130919 usec
# vaex 	 19.674521 usec
# GROUP BY SUM
# datatable 	 0.069049 usec
# pandas 	 0.08538 usec
# polars 	 0.97788 usec
# modin 	 4.194421 usec
# vaex 	 23.93534 usec

# %%
dict_to_df(RESULT_MD, 'Medium')
# Out:
#                   METRIC    LIBRARY  TIME (avg)  TIME (stdv)  TIME (max)  \
# 0               READ_CSV  datatable    9.150714     1.449289   11.469503
# 1               READ_CSV     pandas  140.943228     9.815251  152.724266
# 2               READ_CSV     polars   37.758227     3.629338   44.708800
# 3               READ_CSV      modin   49.846721     3.948500   56.887583
# 4               READ_CSV       vaex    5.508926     1.849561    9.222416
# 5               SAVE_CSV  datatable    5.152349     0.751803    6.643987
# 6               SAVE_CSV     pandas  397.776264     8.630755  410.775149
# 7               SAVE_CSV     polars    7.406933     0.847721    8.189551
# 8               SAVE_CSV      modin  443.226678    13.787912  461.181482
# 9                    NaN        NaN         NaN          NaN         NaN
# 10        PRINT DF SHAPE  datatable    0.000633     0.000646    0.001947
# 11        PRINT DF SHAPE     pandas    0.000485     0.000279    0.001049
# 12        PRINT DF SHAPE     polars    0.000876     0.001246    0.003417
# 13        PRINT DF SHAPE      modin    0.000584     0.000208    0.001001
# 14        PRINT DF SHAPE       vaex    0.001450     0.000513    0.002348
# 15           CREATE COPY  datatable    0.001081     0.001149    0.003417
# 16           CREATE COPY     pandas    5.320282     2.274692    9.623849
# 17           CREATE COPY     polars    0.001330     0.001600    0.004582
# 18           CREATE COPY      modin    0.005005     0.003677    0.012501
# 19           CREATE COPY       vaex    0.071480     0.021224    0.108441
# 20  RENAME SINGLE COLUMN  datatable    0.001455     0.000597    0.002650
# 21  RENAME SINGLE COLUMN     pandas    4.335425     0.039964    4.388817
# 22  RENAME SINGLE COLUMN     polars    0.007010     0.011812    0.031118
# 23  RENAME SINGLE COLUMN      modin    0.062653     0.011066    0.084849
# 24  RENAME SINGLE COLUMN       vaex    0.075974     0.020491    0.114663
# 25    RENAME ALL COLUMNS  datatable    0.001971     0.001278    0.003668
# 26    RENAME ALL COLUMNS     pandas    0.005689     0.000159    0.005968
# 27    RENAME ALL COLUMNS     polars    0.026182     0.022579    0.070484
# 28    RENAME ALL COLUMNS      modin    0.064195     0.012071    0.082350
# 29    RENAME ALL COLUMNS       vaex    4.565752     0.109260    4.731500
# 30       SORT ONE COLUMN  datatable    0.032224     0.041140    0.116114
# 31       SORT ONE COLUMN     pandas    6.196677     0.194074    6.579800
# 32       SORT ONE COLUMN     polars    5.518208     4.601899   14.851769
# 33       SORT ONE COLUMN      modin   48.791028    14.015764   76.628248
# 34       SORT ONE COLUMN       vaex   10.279816     0.595313   11.383597
# 35       SORT TWO COLUMN  datatable    0.177851     0.022952    0.221650
# 36       SORT TWO COLUMN     pandas    7.902062     2.116760   11.546234
# 37       SORT TWO COLUMN     polars    3.752621     0.656369    5.055563
# 38       SORT TWO COLUMN      modin   43.130919     4.094994   48.809381
# 39       SORT TWO COLUMN       vaex   19.674521     0.410557   20.090489
# 40          GROUP BY SUM  datatable    0.069049     0.009535    0.086987
# 41          GROUP BY SUM     pandas    0.085380     0.019288    0.123998
# 42          GROUP BY SUM     polars    0.977880     0.046615    1.030882
# 43          GROUP BY SUM      modin    4.194421     0.392447    4.974854
# 44          GROUP BY SUM       vaex   23.935340     2.194799   28.366486
#
#     TIME (min)    N FILE_SZ
# 0     7.557515  5.0  Medium
# 1   126.329915  5.0  Medium
# 2    35.349298  5.0  Medium
# 3    45.431550  5.0  Medium
# 4     4.262129  5.0  Medium
# 5     4.663869  5.0  Medium
# 6   387.628186  5.0  Medium
# 7     6.022898  5.0  Medium
# 8   420.619766  5.0  Medium
# 9          NaN  NaN  Medium
# 10    0.000334  5.0  Medium
# 11    0.000350  5.0  Medium
# 12    0.000330  5.0  Medium
# 13    0.000469  5.0  Medium
# 14    0.001049  5.0  Medium
# 15    0.000548  5.0  Medium
# 16    4.019189  5.0  Medium
# 17    0.000532  5.0  Medium
# 18    0.003302  5.0  Medium
# 19    0.055798  5.0  Medium
# 20    0.001117  5.0  Medium
# 21    4.284434  5.0  Medium
# 22    0.002019  5.0  Medium
# 23    0.055615  5.0  Medium
# 24    0.063348  5.0  Medium
# 25    0.001065  5.0  Medium
# 26    0.005535  5.0  Medium
# 27    0.011416  5.0  Medium
# 28    0.054006  5.0  Medium
# 29    4.424882  5.0  Medium
# 30    0.013868  5.0  Medium
# 31    6.040482  5.0  Medium
# 32    3.101166  5.0  Medium
# 33   40.312938  5.0  Medium
# 34    9.670130  5.0  Medium
# 35    0.157932  5.0  Medium
# 36    6.255603  5.0  Medium
# 37    3.338615  5.0  Medium
# 38   39.401329  5.0  Medium
# 39   19.002334  5.0  Medium
# 40    0.058746  5.0  Medium
# 41    0.073584  5.0  Medium
# 42    0.912380  5.0  Medium
# 43    3.885651  5.0  Medium
# 44   22.532419  5.0  Medium

# %% [markdown]
# _____
#
# ### ~Large file

# %%
### Deleting dataframes used with the Medium file data
del dtdf, dtdf1, pdf, pdf1, pldf, pldf1, pldf2, mdf, mdf1, vxdf, vxdf1

# %%
file = 'data/data_large.csv'
print("File size: ", np.round(os.stat(file).st_size / (1024 * 1024), 2), "MB")
RESULT_LG = {}
# Out:
# File size:  291.77 MB

# %%
metric = 'READ_CSV'
functiontiming(cmdsrd, metric, RESULT_LG, loop = loops)
metric = 'SAVE_CSV'
os.mkdir(savedir)
functiontiming(sv_cmd, metric, RESULT_LG, loop = loops)
shutil.rmtree(savedir)
metric = 'PRINT DF SHAPE'
functiontiming(cmdshp, metric, RESULT_LG, loop = loops)
metric = 'CREATE COPY'
functiontiming(cmds_copy, metric, RESULT_LG, loop = loops)
metric = 'RENAME SINGLE COLUMN'
functiontiming(cmds_col1, metric, RESULT_LG, add_cmd = cmds_copy, loop = loops)
metric = 'RENAME ALL COLUMNS'
functiontiming(cmds_col_all, metric, RESULT_LG, add_cmd = cmds_copy, loop = loops)
metric = 'SORT ONE COLUMN'
functiontiming(cmds_sort1, metric, RESULT_LG, loop = loops)
metric = 'SORT TWO COLUMN'
functiontiming(cmds_sort2, metric, RESULT_LG, loop = loops)
metric = 'GROUP BY SUM'
functiontiming(grp_by_sum, metric, RESULT_LG, loop = loops)
# Out:
# READ_CSV
# datatable 	 11.69853 usec
# pandas 	 275.377634 usec
# polars 	 42.666442 usec
# modin 	 100.914518 usec
# vaex 	 5.84758 usec
# SAVE_CSV
# datatable 	 8.862489 usec
# pandas 	 796.035378 usec
# polars 	 13.496072 usec
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# modin 	 920.323878 usec
# vaex  ERROR:
#  Error reading csv file data/data_large.csv, write offending chunk to: /var/folders/dg/fckc2gz96c599j8pqfzz6jzr0000gn/T/tmpz2fozfqf.csv (len=10486076, first=False, columns=['SCHOOL_BUS_UNIT'], schema=SCHOOL_BUS_UNIT: int8, encoding=utf8, schema_infer_fraction=0.001).
# Possible causes:
#   * This could be a file encoding error. Consider passing read_options=pyarrow.csv.ReadOptions(encoding="ISO-8859-1") or another encoding as argument.
#   * We might have inferred the wrong schema:
#      * Consider giving a schema hint by e.g. passing read_options=pyarrow.csv.ConvertOptions(column_types={"SomeId": pyarrow.string()}).
#      * Consider increasing schema_infer_fraction (e.g. schema_infer_fraction=1 to parse the whole file to infer the schema).
#
# vaex 	 920.323878 usec
# PRINT DF SHAPE
# datatable 	 0.000859 usec
# pandas 	 0.000454 usec
# polars 	 0.000894 usec
# modin 	 0.000592 usec
# vaex 	 0.00113 usec
# CREATE COPY
# datatable 	 0.001254 usec
# pandas 	 15.997732 usec
# polars 	 0.001201 usec
# modin 	 0.006899 usec
# vaex 	 0.080287 usec
# RENAME SINGLE COLUMN
# datatable 	 0.001396 usec
# pandas 	 13.136605 usec
# polars 	 0.012833 usec
# modin 	 0.0679 usec
# vaex 	 0.091299 usec
# RENAME ALL COLUMNS
# datatable 	 0.001525 usec
# pandas 	 0.005635 usec
# polars 	 0.029883 usec
# modin 	 0.076865 usec
# vaex 	 5.182214 usec
# SORT ONE COLUMN
# datatable 	 0.057731 usec
# pandas 	 16.165878 usec
# polars 	 13.618488 usec
# modin 	 139.847634 usec
# vaex 	 20.79334 usec
# SORT TWO COLUMN
# datatable 	 0.266528 usec
# pandas 	 21.492197 usec
# polars 	 17.122535 usec
# modin 	 179.570813 usec
# vaex 	 38.581383 usec
# GROUP BY SUM
# datatable 	 0.142781 usec
# pandas 	 0.206997 usec
# polars 	 3.913938 usec
# modin 	 5.880813 usec
# vaex 	 446.955692 usec

# %%
dict_to_df(RESULT_LG, 'Large')
# Out:
#                   METRIC    LIBRARY  TIME (avg)  TIME (stdv)   TIME (max)  \
# 0               READ_CSV  datatable   11.698530     1.044659    13.746913
# 1               READ_CSV     pandas  275.377634     8.208701   289.473518
# 2               READ_CSV     polars   42.666442     2.083155    45.658334
# 3               READ_CSV      modin  100.914518    16.455588   128.758887
# 4               READ_CSV       vaex    5.847580     1.621652     8.983370
# 5               SAVE_CSV  datatable    8.862489     1.090098    10.256783
# 6               SAVE_CSV     pandas  796.035378    11.881183   810.363901
# 7               SAVE_CSV     polars   13.496072     1.791367    16.458098
# 8               SAVE_CSV      modin  920.323878    43.049799   962.988802
# 9                    NaN        NaN         NaN          NaN          NaN
# 10        PRINT DF SHAPE  datatable    0.000859     0.000474     0.001582
# 11        PRINT DF SHAPE     pandas    0.000454     0.000175     0.000803
# 12        PRINT DF SHAPE     polars    0.000894     0.001123     0.003183
# 13        PRINT DF SHAPE      modin    0.000592     0.000252     0.001101
# 14        PRINT DF SHAPE       vaex    0.001130     0.000156     0.001427
# 15           CREATE COPY  datatable    0.001254     0.001464     0.004236
# 16           CREATE COPY     pandas   15.997732     7.457603    30.844013
# 17           CREATE COPY     polars    0.001201     0.001411     0.004069
# 18           CREATE COPY      modin    0.006899     0.006939     0.020937
# 19           CREATE COPY       vaex    0.080287     0.025596     0.125353
# 20  RENAME SINGLE COLUMN  datatable    0.001396     0.000560     0.002531
# 21  RENAME SINGLE COLUMN     pandas   13.136605     1.695338    15.328519
# 22  RENAME SINGLE COLUMN     polars    0.012833     0.019119     0.051502
# 23  RENAME SINGLE COLUMN      modin    0.067900     0.017540     0.103096
# 24  RENAME SINGLE COLUMN       vaex    0.091299     0.022405     0.122301
# 25    RENAME ALL COLUMNS  datatable    0.001525     0.000562     0.002579
# 26    RENAME ALL COLUMNS     pandas    0.005635     0.000177     0.005964
# 27    RENAME ALL COLUMNS     polars    0.029883     0.029885     0.087468
# 28    RENAME ALL COLUMNS      modin    0.076865     0.018360     0.103219
# 29    RENAME ALL COLUMNS       vaex    5.182214     0.259626     5.545147
# 30       SORT ONE COLUMN  datatable    0.057731     0.077193     0.215213
# 31       SORT ONE COLUMN     pandas   16.165878     2.103225    20.355848
# 32       SORT ONE COLUMN     polars   13.618488    12.706759    39.525302
# 33       SORT ONE COLUMN      modin  139.847634    49.650257   225.467670
# 34       SORT ONE COLUMN       vaex   20.793340     5.869022    32.564580
# 35       SORT TWO COLUMN  datatable    0.266528     0.099567     0.469216
# 36       SORT TWO COLUMN     pandas   21.492197     7.548219    35.143451
# 37       SORT TWO COLUMN     polars   17.122535    21.950053    61.916999
# 38       SORT TWO COLUMN      modin  179.570813   150.169849   468.444002
# 39       SORT TWO COLUMN       vaex   38.581383     3.539447    44.743816
# 40          GROUP BY SUM  datatable    0.142781     0.061753     0.267780
# 41          GROUP BY SUM     pandas    0.206997     0.150057     0.513252
# 42          GROUP BY SUM     polars    3.913938     4.623574    13.318098
# 43          GROUP BY SUM      modin    5.880813     3.485937    11.940519
# 44          GROUP BY SUM       vaex  446.955692   993.295735  2474.472952
#
#     TIME (min)    N FILE_SZ
# 0    10.931186  5.0   Large
# 1   264.563215  5.0   Large
# 2    40.613782  5.0   Large
# 3    88.554796  5.0   Large
# 4     4.608003  5.0   Large
# 5     7.828899  5.0   Large
# 6   776.003400  5.0   Large
# 7    11.068169  5.0   Large
# 8   866.867701  5.0   Large
# 9          NaN  NaN   Large
# 10    0.000417  5.0   Large
# 11    0.000350  5.0   Large
# 12    0.000366  5.0   Large
# 13    0.000465  5.0   Large
# 14    0.001001  5.0   Large
# 15    0.000548  5.0   Large
# 16   10.880486  5.0   Large
# 17    0.000517  5.0   Large
# 18    0.003401  5.0   Large
# 19    0.058933  5.0   Large
# 20    0.001097  5.0   Large
# 21   11.790315  5.0   Large
# 22    0.002197  5.0   Large
# 23    0.056434  5.0   Large
# 24    0.072396  5.0   Large
# 25    0.001101  5.0   Large
# 26    0.005464  5.0   Large
# 27    0.011595  5.0   Large
# 28    0.055333  5.0   Large
# 29    4.808978  5.0   Large
# 30    0.023238  5.0   Large
# 31   14.590601  5.0   Large
# 32    7.686917  5.0   Large
# 33   84.575498  5.0   Large
# 34   16.964404  5.0   Large
# 35    0.213850  5.0   Large
# 36   14.508752  5.0   Large
# 37    7.571900  5.0   Large
# 38   67.512715  5.0   Large
# 39   35.434584  5.0   Large
# 40    0.108854  5.0   Large
# 41    0.142280  5.0   Large
# 42    1.765200  5.0   Large
# 43    3.615399  5.0   Large
# 44   37.595483  5.0   Large

# %%
client.close()

# %% [markdown]
# ____
#
# # Combining the results

# %%
results = dict_to_df(RESULT_LG).drop(['N'], axis = 1).merge(dict_to_df(RESULT_MD), on = ['METRIC', 'LIBRARY'], suffixes=['_LG', '_MD']).drop(['N'], axis = 1).merge(dict_to_df(RESULT_SM), on = ['METRIC', 'LIBRARY'])
ordered_columns = ['METRIC', 'LIBRARY', 'TIME (avg)_LG', 'TIME (avg)_MD', 'TIME (avg)',
                    'TIME (stdv)_LG', 'TIME (stdv)_MD', 'TIME (stdv)', 
                    'TIME (max)_LG', 'TIME (max)_MD', 'TIME (max)',
                    'TIME (min)_LG', 'TIME (min)_MD', 'TIME (min)', 'N']
results[ordered_columns]
# Out:
#                   METRIC    LIBRARY  TIME (avg)_LG  TIME (avg)_MD  TIME (avg)  \
# 0               READ_CSV  datatable      11.698530       9.150714    3.940627
# 1               READ_CSV     pandas     275.377634     140.943228   25.351358
# 2               READ_CSV     polars      42.666442      37.758227   16.157204
# 3               READ_CSV      modin     100.914518      49.846721   39.581374
# 4               READ_CSV       vaex       5.847580       5.508926   11.292836
# 5               SAVE_CSV  datatable       8.862489       5.152349    0.984232
# 6               SAVE_CSV     pandas     796.035378     397.776264   72.855192
# 7               SAVE_CSV     polars      13.496072       7.406933    1.628870
# 8               SAVE_CSV      modin     920.323878     443.226678   87.246204
# 9         PRINT DF SHAPE  datatable       0.000859       0.000633    0.000414
# 10        PRINT DF SHAPE     pandas       0.000454       0.000485    0.000388
# 11        PRINT DF SHAPE     polars       0.000894       0.000876    0.000411
# 12        PRINT DF SHAPE      modin       0.000592       0.000584    0.000516
# 13        PRINT DF SHAPE       vaex       0.001130       0.001450    0.001003
# 14           CREATE COPY  datatable       0.001254       0.001081    0.000673
# 15           CREATE COPY     pandas      15.997732       5.320282    0.579664
# 16           CREATE COPY     polars       0.001201       0.001330    0.000750
# 17           CREATE COPY      modin       0.006899       0.005005    0.003819
# 18           CREATE COPY       vaex       0.080287       0.071480    0.065703
# 19  RENAME SINGLE COLUMN  datatable       0.001396       0.001455    0.001292
# 20  RENAME SINGLE COLUMN     pandas      13.136605       4.335425    0.427207
# 21  RENAME SINGLE COLUMN     polars       0.012833       0.007010    0.002967
# 22  RENAME SINGLE COLUMN      modin       0.067900       0.062653    0.064530
# 23  RENAME SINGLE COLUMN       vaex       0.091299       0.075974    0.072675
# 24    RENAME ALL COLUMNS  datatable       0.001525       0.001971    0.001176
# 25    RENAME ALL COLUMNS     pandas       0.005635       0.005689    0.007341
# 26    RENAME ALL COLUMNS     polars       0.029883       0.026182    0.018073
# 27    RENAME ALL COLUMNS      modin       0.076865       0.064195    0.067706
# 28    RENAME ALL COLUMNS       vaex       5.182214       4.565752    4.531886
# 29       SORT ONE COLUMN  datatable       0.057731       0.032224    0.014867
# 30       SORT ONE COLUMN     pandas      16.165878       6.196677    0.858475
# 31       SORT ONE COLUMN     polars      13.618488       5.518208    0.628156
# 32       SORT ONE COLUMN      modin     139.847634      48.791028   17.596347
# 33       SORT ONE COLUMN       vaex      20.793340      10.279816    2.896077
# 34       SORT TWO COLUMN  datatable       0.266528       0.177851    0.072828
# 35       SORT TWO COLUMN     pandas      21.492197       7.902062    0.845255
# 36       SORT TWO COLUMN     polars      17.122535       3.752621    0.467051
# 37       SORT TWO COLUMN      modin     179.570813      43.130919   17.933064
# 38       SORT TWO COLUMN       vaex      38.581383      19.674521    5.320963
# 39          GROUP BY SUM  datatable       0.142781       0.069049    0.020727
# 40          GROUP BY SUM     pandas       0.206997       0.085380    0.033396
# 41          GROUP BY SUM     polars       3.913938       0.977880    0.213065
# 42          GROUP BY SUM      modin       5.880813       4.194421    3.655963
# 43          GROUP BY SUM       vaex     446.955692      23.935340   10.301689
#
#     TIME (stdv)_LG  TIME (stdv)_MD  TIME (stdv)  TIME (max)_LG  TIME (max)_MD  \
# 0         1.044659        1.449289     1.066808      13.746913      11.469503
# 1         8.208701        9.815251     0.686571     289.473518     152.724266
# 2         2.083155        3.629338     2.573165      45.658334      44.708800
# 3        16.455588        3.948500    68.146814     128.758887      56.887583
# 4         1.621652        1.849561    16.592047       8.983370       9.222416
# 5         1.090098        0.751803     0.140555      10.256783       6.643987
# 6        11.881183        8.630755     1.136612     810.363901     410.775149
# 7         1.791367        0.847721     0.570921      16.458098       8.189551
# 8        43.049799       13.787912     7.689869     962.988802     461.181482
# 9         0.000474        0.000646     0.000166       0.001582       0.001947
# 10        0.000175        0.000279     0.000139       0.000803       0.001049
# 11        0.001123        0.001246     0.000168       0.003183       0.003417
# 12        0.000252        0.000208     0.000157       0.001101       0.001001
# 13        0.000156        0.000513     0.000133       0.001427       0.002348
# 14        0.001464        0.001149     0.000210       0.004236       0.003417
# 15        7.457603        2.274692     0.319171      30.844013       9.623849
# 16        0.001411        0.001600     0.000368       0.004069       0.004582
# 17        0.006939        0.003677     0.000966       0.020937       0.012501
# 18        0.025596        0.021224     0.007468       0.125353       0.108441
# 19        0.000560        0.000597     0.000329       0.002531       0.002650
# 20        1.695338        0.039964     0.015372      15.328519       4.388817
# 21        0.019119        0.011812     0.002735       0.051502       0.031118
# 22        0.017540        0.011066     0.008368       0.103096       0.084849
# 23        0.022405        0.020491     0.008699       0.122301       0.114663
# 24        0.000562        0.001278     0.000188       0.002579       0.003668
# 25        0.000177        0.000159     0.001477       0.005964       0.005968
# 26        0.029885        0.022579     0.007724       0.087468       0.070484
# 27        0.018360        0.012071     0.014806       0.103219       0.082350
# 28        0.259626        0.109260     0.092871       5.545147       4.731500
# 29        0.077193        0.041140     0.005638       0.215213       0.116114
# 30        2.103225        0.194074     0.198916      20.355848       6.579800
# 31       12.706759        4.601899     0.425498      39.525302      14.851769
# 32       49.650257       14.015764     3.783573     225.467670      76.628248
# 33        5.869022        0.595313     0.699699      32.564580      11.383597
# 34        0.099567        0.022952     0.004279       0.469216       0.221650
# 35        7.548219        2.116760     0.317449      35.143451      11.546234
# 36       21.950053        0.656369     0.034101      61.916999       5.055563
# 37      150.169849        4.094994     2.395777     468.444002      48.809381
# 38        3.539447        0.410557     0.490288      44.743816      20.090489
# 39        0.061753        0.009535     0.003338       0.267780       0.086987
# 40        0.150057        0.019288     0.015517       0.513252       0.123998
# 41        4.623574        0.046615     0.014388      13.318098       1.030882
# 42        3.485937        0.392447     0.187266      11.940519       4.974854
# 43      993.295735        2.194799     1.360323    2474.472952      28.366486
#
#     TIME (max)  TIME (min)_LG  TIME (min)_MD  TIME (min)  N
# 0     6.060481      10.931186       7.557515    3.218969  5
# 1    26.546466     264.563215     126.329915   24.818301  5
# 2    21.246596      40.613782      35.349298   14.663553  5
# 3   178.671499      88.554796      45.431550   10.731900  5
# 4    45.156582       4.608003       4.262129    4.080784  5
# 5     1.189033       7.828899       4.663869    0.807826  5
# 6    74.613603     776.003400     387.628186   71.627132  5
# 7     2.510802      11.068169       6.022898    1.065652  5
# 8   100.682231     866.867701     420.619766   81.026268  5
# 9     0.000735       0.000417       0.000334    0.000298  5
# 10    0.000668       0.000350       0.000350    0.000314  5
# 11    0.000751       0.000366       0.000330    0.000330  5
# 12    0.000834       0.000465       0.000469    0.000433  5
# 13    0.001268       0.001001       0.001049    0.000918  5
# 14    0.001065       0.000548       0.000548    0.000517  5
# 15    1.127434      10.880486       4.019189    0.289599  5
# 16    0.001482       0.000517       0.000532    0.000532  5
# 17    0.005770       0.003401       0.003302    0.003298  5
# 18    0.073834       0.058933       0.055798    0.053902  5
# 19    0.001951       0.001097       0.001117    0.001101  5
# 20    0.456834      11.790315       4.284434    0.413116  5
# 21    0.008535       0.002197       0.002019    0.001669  5
# 22    0.078233       0.056434       0.055615    0.053362  5
# 23    0.088469       0.072396       0.063348    0.064584  5
# 24    0.001498       0.001101       0.001065    0.001001  5
# 25    0.009004       0.005464       0.005535    0.005619  5
# 26    0.030001       0.011595       0.011416    0.010669  5
# 27    0.090265       0.055333       0.054006    0.055635  5
# 28    4.688418       4.808978       4.424882    4.455066  5
# 29    0.026298       0.023238       0.013868    0.011496  5
# 30    1.224848      14.590601       6.040482    0.687738  5
# 31    1.488268       7.686917       3.101166    0.381335  5
# 32   23.409466      84.575498      40.312938   14.550662  5
# 33    4.063805      16.964404       9.670130    2.083862  5
# 34    0.079131       0.213850       0.157932    0.066467  5
# 35    1.486516      14.508752       6.255603    0.685684  5
# 36    0.517567       7.571900       3.338615    0.421087  5
# 37   21.845349      67.512715      39.401329   14.873000  5
# 38    5.887246      35.434584      19.002334    4.713869  5
# 39    0.026850       0.108854       0.058746    0.018104  5
# 40    0.063864       0.142280       0.073584    0.022284  5
# 41    0.229251       1.765200       0.912380    0.191116  5
# 42    4.021736       3.615399       3.885651    3.500267  5
# 43   12.711052      37.595483      22.532419    9.015266  5
