# %% [markdown]
# # PANDAS ALTERNATIVES IN PYTHON
#
# - System:
#
#     Mackbook Pro 15 Inch, 2019
#
#         Processor: 2.3 GHz 8-Core Intel Core i9
#
#         Memory: 16 GB 2400 MHz DDR4
#
#         macOS:  Sonoma 14.5 Beta (23F5049f)
#
# - Python 3.10.9
#
# ______

# %%
# Importing libraries 
import polars as pl
import datatable  as dt
import os
os.environ['MODIN_ENGINE'] = 'dask'
import modin.pandas as md
import modin
print("NUM Partitions available: ", modin.config.NPartitions.get())
# os.environ["MODIN_CPUS"] = "4"
import pandas as pd
import time
import numpy as np
from statistics import mean, stdev
import vaex as vx
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>
# NUM Partitions available:  16

# %%
def exec_time(code_str):
    start = time.time()
    exec(code_str)
    end = time.time()
    return np.round((end-start)/60*1000, 6)

def functiontiming(cmd_d, metr_nm, dictionary, loop = 10, add_cmd = None):
    print(metr_nm)
    for key, cmd in cmd_d.items():
        counter = 0
        times = []
        try: 
            while counter <= loop:
                if add_cmd:
                    new_cmd = add_cmd[key]
                    exec_time(new_cmd)
                time = exec_time(cmd)
                times.append(time)
                counter +=1
            meant = np.round(mean(times), 6)
            stdevt = np.round(stdev(times), 6)
            maxt = np.round(max(times), 6)
            mint = np.round(min(times), 6)
            add_dic = {'METRIC': metr_nm, 'LIBRARY': key, 'TIME (avg)': meant, "TIME (stdv)": stdevt, "TIME (max)": maxt, "TIME (min)": mint,   'N': loop}

        except Exception as E:
            print(key, " ERROR:\n", str(E))
            add_dic = {}

        if metr_nm in dictionary:
            dictionary[metr_nm].append(add_dic)
        else: 
            dictionary[metr_nm] = [add_dic]
        try: 
            print(key, '\t', meant, 'usec')     
        except: print('No data')
        
def dict_to_df(dictionary, file_size = None):
    df = pd.DataFrame()
    for k, v in dictionary.items(): 
        df1 = pd.DataFrame(v)
        df = pd.concat([df, df1], axis = 0).reset_index(drop = True)
    if file_size: 
        df.loc[:,'FILE_SZ'] = file_size
    return df

# %% [markdown]
# ______
# ### ~SMALL FILE

# %%
# Number of data points to calculate statictics 
loops = 5
file = 'data/data_small.csv'
print("File size: ", np.round(os.stat(file).st_size / (1024 * 1024), 2), "MB")
RESULT_SM = {}
# Out:
# File size:  13.84 MB

# %%
cmdsrd = {
        'datatable': 'global dtdf ; dtdf = dt.fread(file)',
        'pandas'   : 'global pdf  ; pdf  = pd.read_csv(file, low_memory = False )',
        'polars'   : 'global pldf ; pldf = pl.read_csv(file, infer_schema_length=100000, ignore_errors = True )',
        'modin'    : 'global mdf  ; mdf  = md.read_csv(file, low_memory = False)',
        'vaex'     : 'global vxdf ; vxdf = vx.open(file)'
        }
metric = 'READ_CSV'
functiontiming(cmdsrd, metric, RESULT_SM, loop = loops)
# Out:
# READ_CSV
# datatable 	 2.180515 usec
# pandas 	 9.385989 usec
# polars 	 7.471109 usec
# UserWarning: Dask execution environment not yet initialized. Initializing...
# To remove this warning, run the following python code before doing dataframe operations:
#
#     from distributed import Client
#
#     client = Client()
#
# UserWarning:
# Dask needs bokeh >= 2.4.2, < 3 for the dashboard.
# You have bokeh==3.0.3.
# Continuing without the dashboard.
# 2024-04-28 19:26:24,947 - distributed.diskutils - INFO - Found stale lock file and directory '/var/folders/dg/fckc2gz96c599j8pqfzz6jzr0000gn/T/dask-worker-space/worker-4fwssqu4', purging
# 2024-04-28 19:26:24,949 - distributed.diskutils - INFO - Found stale lock file and directory '/var/folders/dg/fckc2gz96c599j8pqfzz6jzr0000gn/T/dask-worker-space/worker-x33fjr_k', purging
# 2024-04-28 19:26:24,951 - distributed.diskutils - INFO - Found stale lock file and directory '/var/folders/dg/fckc2gz96c599j8pqfzz6jzr0000gn/T/dask-worker-space/worker-zihxvxo4', purging
# 2024-04-28 19:26:24,952 - distributed.diskutils - INFO - Found stale lock file and directory '/var/folders/dg/fckc2gz96c599j8pqfzz6jzr0000gn/T/dask-worker-space/worker-5iqqcqqg', purging
# 2024-04-28 19:26:24,973 - distributed.diskutils - INFO - Found stale lock file and directory '/var/folders/dg/fckc2gz96c599j8pqfzz6jzr0000gn/T/dask-worker-space/worker-se1r4osr', purging
# 2024-04-28 19:26:24,975 - distributed.diskutils - INFO - Found stale lock file and directory '/var/folders/dg/fckc2gz96c599j8pqfzz6jzr0000gn/T/dask-worker-space/worker-b7zymb51', purging
# 2024-04-28 19:26:24,976 - distributed.diskutils - INFO - Found stale lock file and directory '/var/folders/dg/fckc2gz96c599j8pqfzz6jzr0000gn/T/dask-worker-space/worker-jbk8vgbr', purging
# 2024-04-28 19:26:24,978 - distributed.diskutils - INFO - Found stale lock file and directory '/var/folders/dg/fckc2gz96c599j8pqfzz6jzr0000gn/T/dask-worker-space/worker-0ia1r7up', purging
# 2024-04-28 19:26:24,979 - distributed.diskutils - INFO - Found stale lock file and directory '/var/folders/dg/fckc2gz96c599j8pqfzz6jzr0000gn/T/dask-worker-space/worker-z4cj6kyu', purging
# 2024-04-28 19:26:24,980 - distributed.diskutils - INFO - Found stale lock file and directory '/var/folders/dg/fckc2gz96c599j8pqfzz6jzr0000gn/T/dask-worker-space/worker-8jabap4q', purging
# 2024-04-28 19:26:24,983 - distributed.diskutils - INFO - Found stale lock file and directory '/var/folders/dg/fckc2gz96c599j8pqfzz6jzr0000gn/T/dask-worker-space/worker-va_nuqyf', purging
# 2024-04-28 19:26:24,984 - distributed.diskutils - INFO - Found stale lock file and directory '/var/folders/dg/fckc2gz96c599j8pqfzz6jzr0000gn/T/dask-worker-space/worker-156ltg6c', purging
# 2024-04-28 19:26:24,986 - distributed.diskutils - INFO - Found stale lock file and directory '/var/folders/dg/fckc2gz96c599j8pqfzz6jzr0000gn/T/dask-worker-space/worker-3ir2yt26', purging
# 2024-04-28 19:26:24,987 - distributed.diskutils - INFO - Found stale lock file and directory '/var/folders/dg/fckc2gz96c599j8pqfzz6jzr0000gn/T/dask-worker-space/worker-1sleyur3', purging
# 2024-04-28 19:26:24,988 - distributed.diskutils - INFO - Found stale lock file and directory '/var/folders/dg/fckc2gz96c599j8pqfzz6jzr0000gn/T/dask-worker-space/worker-3s7uvvw1', purging
# 2024-04-28 19:26:24,989 - distributed.diskutils - INFO - Found stale lock file and directory '/var/folders/dg/fckc2gz96c599j8pqfzz6jzr0000gn/T/dask-worker-space/worker-srrj5wb3', purging
# UserWarning: `read_*` implementation has mismatches with pandas:
# Data types of partitions are different! Please refer to the troubleshooting section of the Modin documentation to fix this issue.
# modin 	 29.695955 usec
# vaex 	 6.660628 usec

# %%
cmdshp = {
        'datatable': 'dtdf.shape',
        'pandas'   : 'pdf.shape',
        'polars'   : 'pldf.shape',
        'modin'    : 'mdf.shape',
        'vaex'     : 'vxdf.shape'
        }
metric = 'PRINT DF SHAPE'

functiontiming(cmdshp, metric, RESULT_SM, loop = loops)
# Out:
# PRINT DF SHAPE
# datatable 	 0.000405 usec
# pandas 	 0.000426 usec
# polars 	 0.000504 usec
# modin 	 0.001007 usec
# vaex 	 0.001059 usec

# %%
cmds_copy = {
         'datatable': 'global dtdf1 ; dtdf1 = dtdf.copy()',
         'pandas'  : 'global pdf1  ; pdf1 = pdf.copy()',
         'polars'  : 'global pldf1 ; pldf1 = pldf.clone()',
         'modin'   : 'global mdf1  ; mdf1 = mdf.copy()',
         'vaex'    : 'global vxdf1 ; vxdf1 = vxdf.copy()'
        }
metric = 'CREATE COPY'
functiontiming(cmds_copy, metric, RESULT_SM, loop = loops)
# Out:
# CREATE COPY
# datatable 	 0.000735 usec
# pandas 	 0.330167 usec
# polars 	 0.000908 usec
# modin 	 0.008717 usec
# vaex 	 0.065888 usec

# %%
cmds_col1 = {
         'datatable': 'global dtdf1 ; dtdf1.names = {"CRASH_CRN":"CRASH_CRNnew"}',
         'pandas'   : 'global pdf1  ; pdf1 = pdf1.rename(columns = {"CRASH_CRN":"CRASH_CRNnew"})',
         'polars'   : 'global pldf1 ; pldf1 = pldf1.rename({"CRASH_CRN":"CRASH_CRNnew"})',
         'modin'    : 'global mdf1  ; mdf1 = mdf1.rename(columns = {"CRASH_CRN":"CRASH_CRNnew"})',
         'vaex'     :  'vxdf1.rename("CRASH_CRN","CRASH_CRNnew")'
        }
metric = 'RENAME SINGLE COLUMN'
functiontiming(cmds_col1, metric, RESULT_SM, add_cmd = cmds_copy, loop = loops)
# Out:
# RENAME SINGLE COLUMN
# datatable 	 0.00133 usec
# pandas 	 0.228898 usec
# polars 	 0.003272 usec
# modin 	 0.059962 usec
# vaex 	 0.067348 usec

# %%
new_columns = [col+'NEW' for col in pdf.columns]
new_colums_dict = {}
for col in pdf.columns:
    new_colums_dict[col] = col+'NEW'

cmds_col_all = {
         'datatable': 'global dtdf  ; dtdf.names = new_columns',
         'pandas'   : 'global pdf   ; pdf.columns = new_columns',
         # For polars to work with no errors I had to create a new dataframe. 
         # Tests without new copy in other platforms worked with no issues
         'polars'   : 'global pldf2 ; pldf2 =  pldf.rename(new_colums_dict)',
         'modin'    : 'global mdf   ; mdf = mdf.rename(columns = new_colums_dict)',
         'vaex'     : 'for cur_nm, new_nm in new_colums_dict.items(): vxdf1.rename(cur_nm, new_nm)'
        }
metric = 'RENAME ALL COLUMNS'
functiontiming(cmds_col_all, metric, RESULT_SM, add_cmd = cmds_copy, loop = loops)
# Out:
# RENAME ALL COLUMNS
# datatable 	 0.001216 usec
# pandas 	 0.0059 usec
# polars 	 0.023639 usec
# modin 	 0.059767 usec
# vaex 	 4.59299 usec

# %%
cmds_sort1 = {
         'datatable': 'dtdf[:,:, dt.sort("MUNICIPALITYNEW", reverse=True)]',
         'pandas'   : 'pdf.sort_values(by = ["MUNICIPALITYNEW"], ascending = [False])',
         'polars'   : 'pldf2.sort("MUNICIPALITYNEW", descending=True)',
         'modin'    : 'mdf.sort_values(by = ["MUNICIPALITYNEW"], ascending = [False])',
         'vaex'     : 'vxdf.sort(["MUNICIPALITY"])'
        }
metric = 'SORT ONE COLUMN'
functiontiming(cmds_sort1, metric, RESULT_SM, loop = loops)
# Out:
# SORT ONE COLUMN
# datatable 	 0.018063 usec
# pandas 	 0.392808 usec
# polars 	 0.388208 usec
# modin 	 143.579346 usec
# vaex 	 2.288666 usec

# %%
cmds_sort2 = {
         'datatable': 'dtdf[:,:, dt.sort(["MUNICIPALITYNEW", "CRASH_YEARNEW"], reverse=[True, False])]',
         'pandas'   : 'pdf.sort_values(by = ["MUNICIPALITYNEW", "CRASH_YEARNEW"], ascending = [False, True])',
         'polars'   : 'pldf2.sort("MUNICIPALITYNEW", "CRASH_YEARNEW", descending=[True, False])',
         'modin'    : 'mdf.sort_values(by = ["MUNICIPALITYNEW", "CRASH_YEARNEW"], ascending = [False, True])',
         'vaex'     : 'vxdf.sort(["MUNICIPALITY", "CRASH_YEAR"], ascending = [False, True])'
        }
metric = 'SORT TWO COLUMN'
functiontiming(cmds_sort2, metric, RESULT_SM, loop = loops)
# Out:
# SORT TWO COLUMN
# datatable 	 0.086756 usec
# pandas 	 0.41567 usec
# polars 	 0.302688 usec
# modin 	 139.256868 usec
# vaex 	 3.707558 usec

# %%
from datatable import dt, f, by
grp_by_sum = {
         'datatable': 'dtdf[:, dt.sum(f.CRASH_YEARNEW), by("MUNICIPALITYNEW")]',
         'pandas'   : 'pdf.groupby("MUNICIPALITYNEW")["CRASH_YEARNEW"].sum()',
         'polars'   : 'pldf2.group_by("MUNICIPALITYNEW").agg(pl.sum("CRASH_YEARNEW"))',
         'modin'    : 'mdf.groupby("MUNICIPALITYNEW")["CRASH_YEARNEW"].sum()',
         'vaex'     : "vxdf.groupby(by='MUNICIPALITY').agg({'CRASH_YEAR': 'sum'})"

        }
metric = 'GROUP BY SUM'
functiontiming(grp_by_sum, metric, RESULT_SM, loop = loops)
# Out:
# GROUP BY SUM
# datatable 	 0.018153 usec
# pandas 	 0.028611 usec
# polars 	 0.182442 usec
# modin 	 12.965337 usec
# vaex 	 10.608231 usec

# %%
dict_to_df(RESULT_SM, 'Small')
# Out:
#                   METRIC    LIBRARY  TIME (avg)  TIME (stdv)  TIME (max)  \
# 0               READ_CSV  datatable    2.180515     0.286815    2.760903
# 1               READ_CSV     pandas    9.385989     0.491436    9.973049
# 2               READ_CSV     polars    7.471109     0.389008    8.078452
# 3               READ_CSV      modin   29.695955    44.752793  121.036216
# 4               READ_CSV       vaex    6.660628     6.623980   20.163584
# 5         PRINT DF SHAPE  datatable    0.000405     0.000143    0.000683
# 6         PRINT DF SHAPE     pandas    0.000426     0.000155    0.000735
# 7         PRINT DF SHAPE     polars    0.000504     0.000367    0.001248
# 8         PRINT DF SHAPE      modin    0.001007     0.000534    0.002082
# 9         PRINT DF SHAPE       vaex    0.001059     0.000238    0.001534
# 10           CREATE COPY  datatable    0.000735     0.000341    0.001403
# 11           CREATE COPY     pandas    0.330167     0.185473    0.609795
# 12           CREATE COPY     polars    0.000908     0.000783    0.002499
# 13           CREATE COPY      modin    0.008717     0.002825    0.014285
# 14           CREATE COPY       vaex    0.065888     0.014817    0.093933
# 15  RENAME SINGLE COLUMN  datatable    0.001330     0.000293    0.001864
# 16  RENAME SINGLE COLUMN     pandas    0.228898     0.022499    0.271134
# 17  RENAME SINGLE COLUMN     polars    0.003272     0.003465    0.010331
# 18  RENAME SINGLE COLUMN      modin    0.059962     0.007793    0.075682
# 19  RENAME SINGLE COLUMN       vaex    0.067348     0.002313    0.071232
# 20    RENAME ALL COLUMNS  datatable    0.001216     0.000319    0.001852
# 21    RENAME ALL COLUMNS     pandas    0.005900     0.000373    0.006417
# 22    RENAME ALL COLUMNS     polars    0.023639     0.022517    0.068418
# 23    RENAME ALL COLUMNS      modin    0.059767     0.001733    0.061786
# 24    RENAME ALL COLUMNS       vaex    4.592990     0.081853    4.695797
# 25       SORT ONE COLUMN  datatable    0.018063     0.008352    0.032818
# 26       SORT ONE COLUMN     pandas    0.392808     0.042234    0.456015
# 27       SORT ONE COLUMN     polars    0.388208     0.213927    0.820732
# 28       SORT ONE COLUMN      modin  143.579346    10.102808  161.220582
# 29       SORT ONE COLUMN       vaex    2.288666     0.511324    3.258018
# 30       SORT TWO COLUMN  datatable    0.086756     0.052037    0.190167
# 31       SORT TWO COLUMN     pandas    0.415670     0.175424    0.770215
# 32       SORT TWO COLUMN     polars    0.302688     0.060365    0.404048
# 33       SORT TWO COLUMN      modin  139.256868     8.541074  147.657522
# 34       SORT TWO COLUMN       vaex    3.707558     0.720064    5.081348
# 35          GROUP BY SUM  datatable    0.018153     0.009373    0.037165
# 36          GROUP BY SUM     pandas    0.028611     0.018757    0.066217
# 37          GROUP BY SUM     polars    0.182442     0.088860    0.357819
# 38          GROUP BY SUM      modin   12.965337     1.210310   15.382512
# 39          GROUP BY SUM       vaex   10.608231     1.238808   11.817571
#
#     TIME (min)  N FILE_SZ
# 0     2.001536  5   Small
# 1     8.700069  5   Small
# 2     7.112149  5   Small
# 3    10.645151  5   Small
# 4     3.642901  5   Small
# 5     0.000318  5   Small
# 6     0.000334  5   Small
# 7     0.000314  5   Small
# 8     0.000656  5   Small
# 9     0.000918  5   Small
# 10    0.000513  5   Small
# 11    0.209355  5   Small
# 12    0.000517  5   Small
# 13    0.007117  5   Small
# 14    0.054165  5   Small
# 15    0.001117  5   Small
# 16    0.212252  5   Small
# 17    0.001685  5   Small
# 18    0.055933  5   Small
# 19    0.065021  5   Small
# 20    0.001029  5   Small
# 21    0.005472  5   Small
# 22    0.011249  5   Small
# 23    0.057101  5   Small
# 24    4.481781  5   Small
# 25    0.011349  5   Small
# 26    0.356336  5   Small
# 27    0.272071  5   Small
# 28  132.467965  5   Small
# 29    1.920183  5   Small
# 30    0.053497  5   Small
# 31    0.322382  5   Small
# 32    0.248027  5   Small
# 33  127.471403  5   Small
# 34    3.070879  5   Small
# 35    0.013447  5   Small
# 36    0.016999  5   Small
# 37    0.122472  5   Small
# 38   12.007884  5   Small
# 39    8.352085  5   Small

# %% [markdown]
# _____
#
# ### ~Medium file

# %%
### Deleting dataframes used with the Small file data
del dtdf, dtdf1, pdf, pdf1, pldf, pldf1, pldf2, mdf, mdf1, vxdf, vxdf1

# %%
file = 'data/data_medium.csv'
print("File size: ", np.round(os.stat(file).st_size / (1024 * 1024), 2), "MB")
RESULT_MD = {}
# Out:
# File size:  140.68 MB

# %%
metric = 'READ_CSV'
functiontiming(cmdsrd, metric, RESULT_MD, loop = loops)
metric = 'PRINT DF SHAPE'
functiontiming(cmdshp, metric, RESULT_MD, loop = loops)
metric = 'CREATE COPY'
functiontiming(cmds_copy, metric, RESULT_MD, loop = loops)
metric = 'RENAME SINGLE COLUMN'
functiontiming(cmds_col1, metric, RESULT_MD, add_cmd = cmds_copy, loop = loops)
metric = 'RENAME ALL COLUMNS'
functiontiming(cmds_col_all, metric, RESULT_MD, add_cmd = cmds_copy, loop = loops)
metric = 'SORT ONE COLUMN'
functiontiming(cmds_sort1, metric, RESULT_MD, loop = loops)
metric = 'SORT TWO COLUMN'
functiontiming(cmds_sort2, metric, RESULT_MD, loop = loops)
metric = 'GROUP BY SUM'
functiontiming(grp_by_sum, metric, RESULT_MD, loop = loops)
# Out:
# READ_CSV
# datatable 	 8.880065 usec
# pandas 	 135.542074 usec
# polars 	 38.003842 usec
# modin 	 38.602602 usec
# vaex 	 7.470361 usec
# PRINT DF SHAPE
# datatable 	 0.000493 usec
# pandas 	 0.000434 usec
# polars 	 0.000783 usec
# modin 	 0.001158 usec
# vaex 	 0.003631 usec
# CREATE COPY
# datatable 	 0.000892 usec
# pandas 	 6.948038 usec
# polars 	 0.001204 usec
# modin 	 0.008076 usec
# vaex 	 0.13136 usec
# RENAME SINGLE COLUMN
# datatable 	 0.00149 usec
# pandas 	 6.244391 usec
# polars 	 0.002592 usec
# modin 	 0.077611 usec
# vaex 	 0.104641 usec
# RENAME ALL COLUMNS
# datatable 	 0.003886 usec
# pandas 	 0.007077 usec
# polars 	 0.016958 usec
# modin 	 0.061813 usec
# vaex 	 4.939165 usec
# SORT ONE COLUMN
# datatable 	 0.026308 usec
# pandas 	 6.193146 usec
# polars 	 4.216641 usec
# modin 	 170.131441 usec
# vaex 	 12.942906 usec
# SORT TWO COLUMN
# datatable 	 0.255921 usec
# pandas 	 8.962722 usec
# polars 	 3.347264 usec
# 2024-04-28 19:32:05,706 - distributed.worker - WARNING - Could not find data: {'function-5d575a7d450a477b95e867b63d7322b3': ['tcp://127.0.0.1:54607', 'tcp://127.0.0.1:54616', 'tcp://127.0.0.1:54599', 'tcp://127.0.0.1:54628', 'tcp://127.0.0.1:54637', 'tcp://127.0.0.1:54615', 'tcp://127.0.0.1:54622', 'tcp://127.0.0.1:54598', 'tcp://127.0.0.1:54619']} on workers: [] (who_has: {'function-5d575a7d450a477b95e867b63d7322b3': ['tcp://127.0.0.1:54607', 'tcp://127.0.0.1:54616', 'tcp://127.0.0.1:54599', 'tcp://127.0.0.1:54628', 'tcp://127.0.0.1:54637', 'tcp://127.0.0.1:54615', 'tcp://127.0.0.1:54622', 'tcp://127.0.0.1:54598', 'tcp://127.0.0.1:54619']})
# 2024-04-28 19:32:05,707 - distributed.scheduler - WARNING - Worker tcp://127.0.0.1:54634 failed to acquire keys: {'function-5d575a7d450a477b95e867b63d7322b3': ('tcp://127.0.0.1:54607', 'tcp://127.0.0.1:54616', 'tcp://127.0.0.1:54599', 'tcp://127.0.0.1:54628', 'tcp://127.0.0.1:54637', 'tcp://127.0.0.1:54615', 'tcp://127.0.0.1:54622', 'tcp://127.0.0.1:54598', 'tcp://127.0.0.1:54619')}
# modin 	 157.080745 usec
# vaex 	 23.586046 usec
# GROUP BY SUM
# datatable 	 0.086062 usec
# pandas 	 0.08951 usec
# polars 	 1.120465 usec
# modin 	 13.04252 usec
# vaex 	 28.051453 usec

# %%
dict_to_df(RESULT_MD, 'Medium')
# Out:
#                   METRIC    LIBRARY  TIME (avg)  TIME (stdv)  TIME (max)  \
# 0               READ_CSV  datatable    8.880065     2.711761   14.302631
# 1               READ_CSV     pandas  135.542074     2.961541  140.175903
# 2               READ_CSV     polars   38.003842     3.405680   43.921514
# 3               READ_CSV      modin   38.602602     3.342747   44.505366
# 4               READ_CSV       vaex    7.470361     2.268720   10.796352
# 5         PRINT DF SHAPE  datatable    0.000493     0.000144    0.000679
# 6         PRINT DF SHAPE     pandas    0.000434     0.000141    0.000715
# 7         PRINT DF SHAPE     polars    0.000783     0.000289    0.001351
# 8         PRINT DF SHAPE      modin    0.001158     0.000502    0.001915
# 9         PRINT DF SHAPE       vaex    0.003631     0.002998    0.009203
# 10           CREATE COPY  datatable    0.000892     0.000282    0.001355
# 11           CREATE COPY     pandas    6.948038     4.324914   15.662233
# 12           CREATE COPY     polars    0.001204     0.000928    0.003000
# 13           CREATE COPY      modin    0.008076     0.001239    0.009811
# 14           CREATE COPY       vaex    0.131360     0.052809    0.216901
# 15  RENAME SINGLE COLUMN  datatable    0.001490     0.000537    0.002579
# 16  RENAME SINGLE COLUMN     pandas    6.244391     1.917909    9.338832
# 17  RENAME SINGLE COLUMN     polars    0.002592     0.000965    0.004164
# 18  RENAME SINGLE COLUMN      modin    0.077611     0.017025    0.106585
# 19  RENAME SINGLE COLUMN       vaex    0.104641     0.047364    0.169750
# 20    RENAME ALL COLUMNS  datatable    0.003886     0.002232    0.006902
# 21    RENAME ALL COLUMNS     pandas    0.007077     0.001520    0.009382
# 22    RENAME ALL COLUMNS     polars    0.016958     0.007889    0.029735
# 23    RENAME ALL COLUMNS      modin    0.061813     0.002981    0.066197
# 24    RENAME ALL COLUMNS       vaex    4.939165     0.183234    5.215998
# 25       SORT ONE COLUMN  datatable    0.026308     0.018966    0.064770
# 26       SORT ONE COLUMN     pandas    6.193146     0.084165    6.284320
# 27       SORT ONE COLUMN     polars    4.216641     1.984604    8.210448
# 28       SORT ONE COLUMN      modin  170.131441    10.586447  184.358684
# 29       SORT ONE COLUMN       vaex   12.942906     3.064196   19.086687
# 30       SORT TWO COLUMN  datatable    0.255921     0.057356    0.338085
# 31       SORT TWO COLUMN     pandas    8.962722     1.414641   11.494629
# 32       SORT TWO COLUMN     polars    3.347264     0.181383    3.670684
# 33       SORT TWO COLUMN      modin  157.080745    14.715859  184.618537
# 34       SORT TWO COLUMN       vaex   23.586046     3.498363   30.446450
# 35          GROUP BY SUM  datatable    0.086062     0.049382    0.185164
# 36          GROUP BY SUM     pandas    0.089510     0.015186    0.115601
# 37          GROUP BY SUM     polars    1.120465     0.318650    1.725217
# 38          GROUP BY SUM      modin   13.042520     0.546504   13.628129
# 39          GROUP BY SUM       vaex   28.051453     0.497875   28.642400
#
#     TIME (min)  N FILE_SZ
# 0     7.257346  5  Medium
# 1   132.453398  5  Medium
# 2    35.519850  5  Medium
# 3    36.026851  5  Medium
# 4     5.246333  5  Medium
# 5     0.000370  5  Medium
# 6     0.000350  5  Medium
# 7     0.000548  5  Medium
# 8     0.000648  5  Medium
# 9     0.001462  5  Medium
# 10    0.000648  5  Medium
# 11    4.635330  5  Medium
# 12    0.000620  5  Medium
# 13    0.007085  5  Medium
# 14    0.068915  5  Medium
# 15    0.001220  5  Medium
# 16    4.816051  5  Medium
# 17    0.001784  5  Medium
# 18    0.065366  5  Medium
# 19    0.068831  5  Medium
# 20    0.001836  5  Medium
# 21    0.005615  5  Medium
# 22    0.010935  5  Medium
# 23    0.058552  5  Medium
# 24    4.694513  5  Medium
# 25    0.016967  5  Medium
# 26    6.064181  5  Medium
# 27    2.973700  5  Medium
# 28  161.304637  5  Medium
# 29   11.201282  5  Medium
# 30    0.195750  5  Medium
# 31    7.448999  5  Medium
# 32    3.135363  5  Medium
# 33  141.629418  5  Medium
# 34   21.016979  5  Medium
# 35    0.057880  5  Medium
# 36    0.073846  5  Medium
# 37    0.873884  5  Medium
# 38   12.433116  5  Medium
# 39   27.303239  5  Medium

# %% [markdown]
# _____
#
# ### ~Large file

# %%
### Deleting dataframes used with the Medium file data
del dtdf, dtdf1, pdf, pdf1, pldf, pldf1, pldf2, mdf, mdf1, vxdf, vxdf1

# %%
file = 'data/data_large.csv'
print("File size: ", np.round(os.stat(file).st_size / (1024 * 1024), 2), "MB")
RESULT_LG = {}
# Out:
# File size:  281.36 MB

# %%
metric = 'READ_CSV'
functiontiming(cmdsrd, metric, RESULT_LG, loop = loops)
metric = 'PRINT DF SHAPE'
functiontiming(cmdshp, metric, RESULT_LG, loop = loops)
metric = 'CREATE COPY'
functiontiming(cmds_copy, metric, RESULT_LG, loop = loops)
metric = 'RENAME SINGLE COLUMN'
functiontiming(cmds_col1, metric, RESULT_LG, add_cmd = cmds_copy, loop = loops)
metric = 'RENAME ALL COLUMNS'
functiontiming(cmds_col_all, metric, RESULT_LG, add_cmd = cmds_copy, loop = loops)
metric = 'SORT ONE COLUMN'
functiontiming(cmds_sort1, metric, RESULT_LG, loop = loops)
metric = 'SORT TWO COLUMN'
functiontiming(cmds_sort2, metric, RESULT_LG, loop = loops)
metric = 'GROUP BY SUM'
functiontiming(grp_by_sum, metric, RESULT_LG, loop = loops)
# Out:
# READ_CSV
# datatable 	 12.466177 usec
# pandas 	 265.811959 usec
# polars 	 41.484716 usec
# modin 	 71.544194 usec
# vaex 	 6.068185 usec
# PRINT DF SHAPE
# datatable 	 0.000508 usec
# pandas 	 0.00043 usec
# polars 	 0.000783 usec
# modin 	 0.000995 usec
# vaex 	 0.001198 usec
# CREATE COPY
# datatable 	 0.001066 usec
# pandas 	 12.074617 usec
# polars 	 0.001089 usec
# modin 	 0.008029 usec
# vaex 	 0.074164 usec
# RENAME SINGLE COLUMN
# datatable 	 0.001547 usec
# pandas 	 10.514478 usec
# polars 	 0.007502 usec
# modin 	 0.06067 usec
# vaex 	 0.068167 usec
# RENAME ALL COLUMNS
# datatable 	 0.013574 usec
# pandas 	 0.005728 usec
# polars 	 0.043584 usec
# modin 	 0.061666 usec
# vaex 	 4.948886 usec
# SORT ONE COLUMN
# datatable 	 0.050322 usec
# pandas 	 16.755631 usec
# polars 	 10.606325 usec
# 2024-04-28 19:35:41,282 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 852.41 MiB -- Worker memory limit: 1.00 GiB
# 2024-04-28 19:35:41,642 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:54607 (pid=19194) exceeded 95% memory budget. Restarting...
# 2024-04-28 19:35:42,216 - distributed.nanny - WARNING - Restarting worker
# 2024-04-28 19:35:46,293 - distributed.worker.memory - WARNING - Worker is at 89% memory usage. Pausing worker.  Process memory: 913.29 MiB -- Worker memory limit: 1.00 GiB
# 2024-04-28 19:35:46,399 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:54604 (pid=19192) exceeded 95% memory budget. Restarting...
# 2024-04-28 19:35:46,526 - distributed.nanny - WARNING - Restarting worker
# 2024-04-28 19:35:49,767 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 850.32 MiB -- Worker memory limit: 1.00 GiB
# 2024-04-28 19:35:49,875 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:54616 (pid=19196) exceeded 95% memory budget. Restarting...
# 2024-04-28 19:35:50,054 - distributed.nanny - WARNING - Restarting worker
# 2024-04-28 19:35:54,566 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 852.52 MiB -- Worker memory limit: 1.00 GiB
# 2024-04-28 19:35:54,968 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:54615 (pid=19195) exceeded 95% memory budget. Restarting...
# 2024-04-28 19:35:55,125 - distributed.nanny - WARNING - Restarting worker
# modin  ERROR:
#  lambda-d3950906e45b4b068f222cc5a451e9bf
# modin 	 10.606325 usec
# 2024-04-28 19:36:00,089 - distributed.worker - ERROR - Exception during execution of task deploy_dask_func-d6a4be2f-7cd5-4e90-8d82-3bdb822eb43f.
# Traceback (most recent call last):
#   File "/Users/jorgepinzon/opt/anaconda3/envs/py310/lib/python3.10/site-packages/distributed/worker.py", line 2366, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/Users/jorgepinzon/opt/anaconda3/envs/py310/lib/python3.10/site-packages/distributed/spill.py", line 257, in __getitem__
#     return super().__getitem__(key)
#   File "/Users/jorgepinzon/opt/anaconda3/envs/py310/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'lambda-6ab893161f39db276beb204c0b4b6fa2'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/jorgepinzon/opt/anaconda3/envs/py310/lib/python3.10/site-packages/distributed/worker.py", line 2247, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/Users/jorgepinzon/opt/anaconda3/envs/py310/lib/python3.10/site-packages/distributed/worker.py", line 2370, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'lambda-6ab893161f39db276beb204c0b4b6fa2'
# 2024-04-28 19:36:00,143 - distributed.worker - ERROR - Exception during execution of task deploy_dask_func-d0b50949-0677-4a23-ae3d-e5f28923a8b6.
# Traceback (most recent call last):
#   File "/Users/jorgepinzon/opt/anaconda3/envs/py310/lib/python3.10/site-packages/distributed/worker.py", line 2366, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/Users/jorgepinzon/opt/anaconda3/envs/py310/lib/python3.10/site-packages/distributed/spill.py", line 257, in __getitem__
#     return super().__getitem__(key)
#   File "/Users/jorgepinzon/opt/anaconda3/envs/py310/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'lambda-2ff85f6b3f4ccc6799d0d7bb6132cebd'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/jorgepinzon/opt/anaconda3/envs/py310/lib/python3.10/site-packages/distributed/worker.py", line 2247, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/Users/jorgepinzon/opt/anaconda3/envs/py310/lib/python3.10/site-packages/distributed/worker.py", line 2370, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'lambda-2ff85f6b3f4ccc6799d0d7bb6132cebd'
# 2024-04-28 19:36:00,155 - distributed.worker - ERROR - Exception during execution of task deploy_dask_func-b0b2ff22-ea04-46c3-9d43-5c1e80732ff7.
# Traceback (most recent call last):
#   File "/Users/jorgepinzon/opt/anaconda3/envs/py310/lib/python3.10/site-packages/distributed/worker.py", line 2366, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/Users/jorgepinzon/opt/anaconda3/envs/py310/lib/python3.10/site-packages/distributed/spill.py", line 257, in __getitem__
#     return super().__getitem__(key)
#   File "/Users/jorgepinzon/opt/anaconda3/envs/py310/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'lambda-da19f956953c79579cc229b76a03b0b6'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/jorgepinzon/opt/anaconda3/envs/py310/lib/python3.10/site-packages/distributed/worker.py", line 2247, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/Users/jorgepinzon/opt/anaconda3/envs/py310/lib/python3.10/site-packages/distributed/worker.py", line 2370, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'lambda-da19f956953c79579cc229b76a03b0b6'
# 2024-04-28 19:36:00,159 - distributed.worker - ERROR - Exception during execution of task lambda-6ea06d448e7b7da30e9c2bc2d23e6ccb.
# Traceback (most recent call last):
#   File "/Users/jorgepinzon/opt/anaconda3/envs/py310/lib/python3.10/site-packages/distributed/worker.py", line 2366, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/Users/jorgepinzon/opt/anaconda3/envs/py310/lib/python3.10/site-packages/distributed/spill.py", line 257, in __getitem__
#     return super().__getitem__(key)
#   File "/Users/jorgepinzon/opt/anaconda3/envs/py310/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'split_fn-7828c93980cbfd063d65ca979394745d'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/jorgepinzon/opt/anaconda3/envs/py310/lib/python3.10/site-packages/distributed/worker.py", line 2247, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/Users/jorgepinzon/opt/anaconda3/envs/py310/lib/python3.10/site-packages/distributed/worker.py", line 2370, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'split_fn-7828c93980cbfd063d65ca979394745d'
# 2024-04-28 19:36:00,171 - distributed.worker - ERROR - Exception during execution of task deploy_dask_func-1e6efcab-b7a6-4e64-91f9-4a7a07054c09.
# Traceback (most recent call last):
#   File "/Users/jorgepinzon/opt/anaconda3/envs/py310/lib/python3.10/site-packages/distributed/worker.py", line 2366, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/Users/jorgepinzon/opt/anaconda3/envs/py310/lib/python3.10/site-packages/distributed/spill.py", line 257, in __getitem__
#     return super().__getitem__(key)
#   File "/Users/jorgepinzon/opt/anaconda3/envs/py310/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'lambda-4450cd6b81035d6a37f5383288cd0e36'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/jorgepinzon/opt/anaconda3/envs/py310/lib/python3.10/site-packages/distributed/worker.py", line 2247, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/Users/jorgepinzon/opt/anaconda3/envs/py310/lib/python3.10/site-packages/distributed/worker.py", line 2370, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'lambda-4450cd6b81035d6a37f5383288cd0e36'
# vaex 	 28.895834 usec
# SORT TWO COLUMN
# datatable 	 0.281839 usec
# pandas 	 17.64547 usec
# polars 	 12.881739 usec
# 2024-04-28 19:36:26,938 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 843.52 MiB -- Worker memory limit: 1.00 GiB
# 2024-04-28 19:36:27,454 - distributed.worker.memory - WARNING - Worker is at 74% memory usage. Resuming worker. Process memory: 758.81 MiB -- Worker memory limit: 1.00 GiB
# 2024-04-28 19:36:27,785 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 844.48 MiB -- Worker memory limit: 1.00 GiB
# 2024-04-28 19:36:28,447 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:55497 (pid=22221) exceeded 95% memory budget. Restarting...
# 2024-04-28 19:36:29,447 - distributed.nanny - WARNING - Restarting worker
# 2024-04-28 19:36:33,291 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 834.68 MiB -- Worker memory limit: 1.00 GiB
# 2024-04-28 19:36:33,448 - distributed.worker.memory - WARNING - Worker is at 68% memory usage. Resuming worker. Process memory: 698.07 MiB -- Worker memory limit: 1.00 GiB
# 2024-04-28 19:36:33,697 - distributed.worker.memory - WARNING - Worker is at 88% memory usage. Pausing worker.  Process memory: 904.09 MiB -- Worker memory limit: 1.00 GiB
# 2024-04-28 19:36:34,051 - distributed.worker.memory - WARNING - Worker is at 72% memory usage. Resuming worker. Process memory: 746.10 MiB -- Worker memory limit: 1.00 GiB
# 2024-04-28 19:36:34,239 - distributed.worker.memory - WARNING - Worker is at 87% memory usage. Pausing worker.  Process memory: 893.64 MiB -- Worker memory limit: 1.00 GiB
# 2024-04-28 19:36:34,352 - distributed.worker.memory - WARNING - Worker is at 74% memory usage. Resuming worker. Process memory: 765.44 MiB -- Worker memory limit: 1.00 GiB
# 2024-04-28 19:36:34,427 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 763.10 MiB -- Worker memory limit: 1.00 GiB
# 2024-04-28 19:36:44,596 - distributed.worker.memory - WARNING - Worker is at 85% memory usage. Pausing worker.  Process memory: 877.86 MiB -- Worker memory limit: 1.00 GiB
# 2024-04-28 19:36:44,745 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:54622 (pid=19198) exceeded 95% memory budget. Restarting...
# 2024-04-28 19:36:45,363 - distributed.nanny - WARNING - Restarting worker
# 2024-04-28 19:36:49,953 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 853.70 MiB -- Worker memory limit: 1.00 GiB
# 2024-04-28 19:36:50,096 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:54597 (pid=19188) exceeded 95% memory budget. Restarting...
# 2024-04-28 19:36:50,332 - distributed.nanny - WARNING - Restarting worker
# 2024-04-28 19:36:54,643 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 845.17 MiB -- Worker memory limit: 1.00 GiB
# 2024-04-28 19:36:54,826 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:54625 (pid=19199) exceeded 95% memory budget. Restarting...
# 2024-04-28 19:36:54,993 - distributed.nanny - WARNING - Restarting worker
# 2024-04-28 19:36:59,422 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 841.84 MiB -- Worker memory limit: 1.00 GiB
# 2024-04-28 19:36:59,612 - distributed.worker.memory - WARNING - Worker is at 75% memory usage. Resuming worker. Process memory: 773.64 MiB -- Worker memory limit: 1.00 GiB
# 2024-04-28 19:36:59,735 - distributed.worker.memory - WARNING - Worker is at 85% memory usage. Pausing worker.  Process memory: 873.25 MiB -- Worker memory limit: 1.00 GiB
# 2024-04-28 19:37:00,076 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.00 GiB -- Worker memory limit: 1.00 GiB
# 2024-04-28 19:37:00,091 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.02 GiB -- Worker memory limit: 1.00 GiB
# 2024-04-28 19:37:00,116 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:55623 (pid=22476) exceeded 95% memory budget. Restarting...
# 2024-04-28 19:37:00,349 - distributed.nanny - WARNING - Restarting worker
# modin  ERROR:
#  Attempted to run task deploy_dask_func-f696886b-5420-48ac-8cf1-7ff0758f423b on 3 different workers, but all those workers died while running it. The last worker that attempt to run the task was tcp://127.0.0.1:55623. Inspecting worker logs is often a good next step to diagnose what went wrong. For more information see https://distributed.dask.org/en/stable/killed.html.
# modin 	 12.881739 usec
# vaex 	 52.840092 usec
# GROUP BY SUM
# datatable 	 0.158898 usec
# pandas 	 0.212437 usec
# polars 	 2.686306 usec
# modin 	 14.727121 usec
# vaex 	 53.103473 usec

# %%
dict_to_df(RESULT_LG, 'Large')
# Out:
#                   METRIC    LIBRARY  TIME (avg)  TIME (stdv)  TIME (max)  \
# 0               READ_CSV  datatable   12.466177     1.161104   14.387182
# 1               READ_CSV     pandas  265.811959     7.681462  275.931839
# 2               READ_CSV     polars   41.484716     1.910927   44.709917
# 3               READ_CSV      modin   71.544194     8.202934   85.593065
# 4               READ_CSV       vaex    6.068185     2.546072   11.226066
# 5         PRINT DF SHAPE  datatable    0.000508     0.000345    0.001204
# 6         PRINT DF SHAPE     pandas    0.000430     0.000133    0.000699
# 7         PRINT DF SHAPE     polars    0.000783     0.000995    0.002813
# 8         PRINT DF SHAPE      modin    0.000995     0.001130    0.003298
# 9         PRINT DF SHAPE       vaex    0.001198     0.000479    0.002170
# 10           CREATE COPY  datatable    0.001066     0.001000    0.003099
# 11           CREATE COPY     pandas   12.074617     4.682015   21.566665
# 12           CREATE COPY     polars    0.001089     0.001113    0.003350
# 13           CREATE COPY      modin    0.008029     0.001885    0.011814
# 14           CREATE COPY       vaex    0.074164     0.018951    0.101415
# 15  RENAME SINGLE COLUMN  datatable    0.001547     0.000545    0.002579
# 16  RENAME SINGLE COLUMN     pandas   10.514478     0.129217   10.732134
# 17  RENAME SINGLE COLUMN     polars    0.007502     0.009018    0.024068
# 18  RENAME SINGLE COLUMN      modin    0.060670     0.005429    0.071720
# 19  RENAME SINGLE COLUMN       vaex    0.068167     0.003352    0.074697
# 20    RENAME ALL COLUMNS  datatable    0.013574     0.030128    0.075070
# 21    RENAME ALL COLUMNS     pandas    0.005728     0.000138    0.005949
# 22    RENAME ALL COLUMNS     polars    0.043584     0.050880    0.137234
# 23    RENAME ALL COLUMNS      modin    0.061666     0.003539    0.066499
# 24    RENAME ALL COLUMNS       vaex    4.948886     0.234838    5.277054
# 25       SORT ONE COLUMN  datatable    0.050322     0.053403    0.159188
# 26       SORT ONE COLUMN     pandas   16.755631     2.030106   20.446114
# 27       SORT ONE COLUMN     polars   10.606325     7.366249   25.637134
# 28                   NaN        NaN         NaN          NaN         NaN
# 29       SORT ONE COLUMN       vaex   28.895834    14.620058   58.532786
# 30       SORT TWO COLUMN  datatable    0.281839     0.105343    0.485031
# 31       SORT TWO COLUMN     pandas   17.645470     5.355744   28.421001
# 32       SORT TWO COLUMN     polars   12.881739    11.126130   35.555355
# 33                   NaN        NaN         NaN          NaN         NaN
# 34       SORT TWO COLUMN       vaex   52.840092    11.780762   76.816134
# 35          GROUP BY SUM  datatable    0.158898     0.077058    0.313783
# 36          GROUP BY SUM     pandas    0.212437     0.110580    0.437085
# 37          GROUP BY SUM     polars    2.686306     1.659423    6.063934
# 38          GROUP BY SUM      modin   14.727121     1.766758   18.234813
# 39          GROUP BY SUM       vaex   53.103473     1.144629   54.608599
#
#     TIME (min)    N FILE_SZ
# 0    11.533419  5.0   Large
# 1   253.054734  5.0   Large
# 2    39.967589  5.0   Large
# 3    64.507099  5.0   Large
# 4     4.519550  5.0   Large
# 5     0.000334  5.0   Large
# 6     0.000350  5.0   Large
# 7     0.000330  5.0   Large
# 8     0.000481  5.0   Large
# 9     0.000966  5.0   Large
# 10    0.000548  5.0   Large
# 11    9.586362  5.0   Large
# 12    0.000552  5.0   Large
# 13    0.007049  5.0   Large
# 14    0.053779  5.0   Large
# 15    0.001188  5.0   Large
# 16   10.372535  5.0   Large
# 17    0.001733  5.0   Large
# 18    0.057669  5.0   Large
# 19    0.065347  5.0   Large
# 20    0.001069  5.0   Large
# 21    0.005551  5.0   Large
# 22    0.011313  5.0   Large
# 23    0.058703  5.0   Large
# 24    4.681853  5.0   Large
# 25    0.025352  5.0   Large
# 26   14.824168  5.0   Large
# 27    7.382933  5.0   Large
# 28         NaN  NaN   Large
# 29   21.455729  5.0   Large
# 30    0.218515  5.0   Large
# 31   14.705567  5.0   Large
# 32    7.596548  5.0   Large
# 33         NaN  NaN   Large
# 34   46.824018  5.0   Large
# 35    0.114866  5.0   Large
# 36    0.152036  5.0   Large
# 37    1.846349  5.0   Large
# 38   13.660347  5.0   Large
# 39   51.463302  5.0   Large

# %% [markdown]
# ____
#
# # Combining the results

# %%
results = dict_to_df(RESULT_LG).drop(['N'], axis = 1).merge(dict_to_df(RESULT_MD), on = ['METRIC', 'LIBRARY'], suffixes=['_LG', '_MD']).drop(['N'], axis = 1).merge(dict_to_df(RESULT_SM), on = ['METRIC', 'LIBRARY'])
ordered_columns = ['METRIC', 'LIBRARY', 'TIME (avg)_LG', 'TIME (avg)_MD', 'TIME (avg)',
                    'TIME (stdv)_LG', 'TIME (stdv)_MD', 'TIME (stdv)', 
                    'TIME (max)_LG', 'TIME (max)_MD', 'TIME (max)',
                    'TIME (min)_LG', 'TIME (min)_MD', 'TIME (min)', 'N']
results[ordered_columns]
# Out:
#                   METRIC    LIBRARY  TIME (avg)_LG  TIME (avg)_MD  TIME (avg)  \
# 0               READ_CSV  datatable      12.466177       8.880065    2.180515
# 1               READ_CSV     pandas     265.811959     135.542074    9.385989
# 2               READ_CSV     polars      41.484716      38.003842    7.471109
# 3               READ_CSV      modin      71.544194      38.602602   29.695955
# 4               READ_CSV       vaex       6.068185       7.470361    6.660628
# 5         PRINT DF SHAPE  datatable       0.000508       0.000493    0.000405
# 6         PRINT DF SHAPE     pandas       0.000430       0.000434    0.000426
# 7         PRINT DF SHAPE     polars       0.000783       0.000783    0.000504
# 8         PRINT DF SHAPE      modin       0.000995       0.001158    0.001007
# 9         PRINT DF SHAPE       vaex       0.001198       0.003631    0.001059
# 10           CREATE COPY  datatable       0.001066       0.000892    0.000735
# 11           CREATE COPY     pandas      12.074617       6.948038    0.330167
# 12           CREATE COPY     polars       0.001089       0.001204    0.000908
# 13           CREATE COPY      modin       0.008029       0.008076    0.008717
# 14           CREATE COPY       vaex       0.074164       0.131360    0.065888
# 15  RENAME SINGLE COLUMN  datatable       0.001547       0.001490    0.001330
# 16  RENAME SINGLE COLUMN     pandas      10.514478       6.244391    0.228898
# 17  RENAME SINGLE COLUMN     polars       0.007502       0.002592    0.003272
# 18  RENAME SINGLE COLUMN      modin       0.060670       0.077611    0.059962
# 19  RENAME SINGLE COLUMN       vaex       0.068167       0.104641    0.067348
# 20    RENAME ALL COLUMNS  datatable       0.013574       0.003886    0.001216
# 21    RENAME ALL COLUMNS     pandas       0.005728       0.007077    0.005900
# 22    RENAME ALL COLUMNS     polars       0.043584       0.016958    0.023639
# 23    RENAME ALL COLUMNS      modin       0.061666       0.061813    0.059767
# 24    RENAME ALL COLUMNS       vaex       4.948886       4.939165    4.592990
# 25       SORT ONE COLUMN  datatable       0.050322       0.026308    0.018063
# 26       SORT ONE COLUMN     pandas      16.755631       6.193146    0.392808
# 27       SORT ONE COLUMN     polars      10.606325       4.216641    0.388208
# 28       SORT ONE COLUMN       vaex      28.895834      12.942906    2.288666
# 29       SORT TWO COLUMN  datatable       0.281839       0.255921    0.086756
# 30       SORT TWO COLUMN     pandas      17.645470       8.962722    0.415670
# 31       SORT TWO COLUMN     polars      12.881739       3.347264    0.302688
# 32       SORT TWO COLUMN       vaex      52.840092      23.586046    3.707558
# 33          GROUP BY SUM  datatable       0.158898       0.086062    0.018153
# 34          GROUP BY SUM     pandas       0.212437       0.089510    0.028611
# 35          GROUP BY SUM     polars       2.686306       1.120465    0.182442
# 36          GROUP BY SUM      modin      14.727121      13.042520   12.965337
# 37          GROUP BY SUM       vaex      53.103473      28.051453   10.608231
#
#     TIME (stdv)_LG  TIME (stdv)_MD  TIME (stdv)  TIME (max)_LG  TIME (max)_MD  \
# 0         1.161104        2.711761     0.286815      14.387182      14.302631
# 1         7.681462        2.961541     0.491436     275.931839     140.175903
# 2         1.910927        3.405680     0.389008      44.709917      43.921514
# 3         8.202934        3.342747    44.752793      85.593065      44.505366
# 4         2.546072        2.268720     6.623980      11.226066      10.796352
# 5         0.000345        0.000144     0.000143       0.001204       0.000679
# 6         0.000133        0.000141     0.000155       0.000699       0.000715
# 7         0.000995        0.000289     0.000367       0.002813       0.001351
# 8         0.001130        0.000502     0.000534       0.003298       0.001915
# 9         0.000479        0.002998     0.000238       0.002170       0.009203
# 10        0.001000        0.000282     0.000341       0.003099       0.001355
# 11        4.682015        4.324914     0.185473      21.566665      15.662233
# 12        0.001113        0.000928     0.000783       0.003350       0.003000
# 13        0.001885        0.001239     0.002825       0.011814       0.009811
# 14        0.018951        0.052809     0.014817       0.101415       0.216901
# 15        0.000545        0.000537     0.000293       0.002579       0.002579
# 16        0.129217        1.917909     0.022499      10.732134       9.338832
# 17        0.009018        0.000965     0.003465       0.024068       0.004164
# 18        0.005429        0.017025     0.007793       0.071720       0.106585
# 19        0.003352        0.047364     0.002313       0.074697       0.169750
# 20        0.030128        0.002232     0.000319       0.075070       0.006902
# 21        0.000138        0.001520     0.000373       0.005949       0.009382
# 22        0.050880        0.007889     0.022517       0.137234       0.029735
# 23        0.003539        0.002981     0.001733       0.066499       0.066197
# 24        0.234838        0.183234     0.081853       5.277054       5.215998
# 25        0.053403        0.018966     0.008352       0.159188       0.064770
# 26        2.030106        0.084165     0.042234      20.446114       6.284320
# 27        7.366249        1.984604     0.213927      25.637134       8.210448
# 28       14.620058        3.064196     0.511324      58.532786      19.086687
# 29        0.105343        0.057356     0.052037       0.485031       0.338085
# 30        5.355744        1.414641     0.175424      28.421001      11.494629
# 31       11.126130        0.181383     0.060365      35.555355       3.670684
# 32       11.780762        3.498363     0.720064      76.816134      30.446450
# 33        0.077058        0.049382     0.009373       0.313783       0.185164
# 34        0.110580        0.015186     0.018757       0.437085       0.115601
# 35        1.659423        0.318650     0.088860       6.063934       1.725217
# 36        1.766758        0.546504     1.210310      18.234813      13.628129
# 37        1.144629        0.497875     1.238808      54.608599      28.642400
#
#     TIME (max)  TIME (min)_LG  TIME (min)_MD  TIME (min)  N
# 0     2.760903      11.533419       7.257346    2.001536  5
# 1     9.973049     253.054734     132.453398    8.700069  5
# 2     8.078452      39.967589      35.519850    7.112149  5
# 3   121.036216      64.507099      36.026851   10.645151  5
# 4    20.163584       4.519550       5.246333    3.642901  5
# 5     0.000683       0.000334       0.000370    0.000318  5
# 6     0.000735       0.000350       0.000350    0.000334  5
# 7     0.001248       0.000330       0.000548    0.000314  5
# 8     0.002082       0.000481       0.000648    0.000656  5
# 9     0.001534       0.000966       0.001462    0.000918  5
# 10    0.001403       0.000548       0.000648    0.000513  5
# 11    0.609795       9.586362       4.635330    0.209355  5
# 12    0.002499       0.000552       0.000620    0.000517  5
# 13    0.014285       0.007049       0.007085    0.007117  5
# 14    0.093933       0.053779       0.068915    0.054165  5
# 15    0.001864       0.001188       0.001220    0.001117  5
# 16    0.271134      10.372535       4.816051    0.212252  5
# 17    0.010331       0.001733       0.001784    0.001685  5
# 18    0.075682       0.057669       0.065366    0.055933  5
# 19    0.071232       0.065347       0.068831    0.065021  5
# 20    0.001852       0.001069       0.001836    0.001029  5
# 21    0.006417       0.005551       0.005615    0.005472  5
# 22    0.068418       0.011313       0.010935    0.011249  5
# 23    0.061786       0.058703       0.058552    0.057101  5
# 24    4.695797       4.681853       4.694513    4.481781  5
# 25    0.032818       0.025352       0.016967    0.011349  5
# 26    0.456015      14.824168       6.064181    0.356336  5
# 27    0.820732       7.382933       2.973700    0.272071  5
# 28    3.258018      21.455729      11.201282    1.920183  5
# 29    0.190167       0.218515       0.195750    0.053497  5
# 30    0.770215      14.705567       7.448999    0.322382  5
# 31    0.404048       7.596548       3.135363    0.248027  5
# 32    5.081348      46.824018      21.016979    3.070879  5
# 33    0.037165       0.114866       0.057880    0.013447  5
# 34    0.066217       0.152036       0.073846    0.016999  5
# 35    0.357819       1.846349       0.873884    0.122472  5
# 36   15.382512      13.660347      12.433116   12.007884  5
# 37   11.817571      51.463302      27.303239    8.352085  5
