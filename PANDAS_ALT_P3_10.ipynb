# %% [markdown]
# # PANDAS ALTERNATIVES IN PYTHON
#
# - System:
#
#     Mackbook Pro 15 Inch, 2019
#
#         Processor: 2.3 GHz 8-Core Intel Core i9
#
#         Memory: 16 GB 2400 MHz DDR4
#
#         macOS:  Sonoma 14.5 Beta (23F5049f)
#
# - Python 3.10.9
#
# ______

# %%
# Importing libraries 
import polars as pl
import datatable  as dt
import os
os.environ['MODIN_ENGINE'] = 'dask'
import modin.pandas as md
import modin
print("NUM Partitions available: ", modin.config.NPartitions.get())
# os.environ["MODIN_CPUS"] = "4"
import pandas as pd
import time
import numpy as np
from statistics import mean, stdev
import vaex as vx

# Initializing dask 
# from distributed import Client
# client = Client() 
from dask.distributed import Client
client = Client()
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>
# NUM Partitions available:  16
# UserWarning:
# Dask needs bokeh >= 2.4.2, < 3 for the dashboard.
# You have bokeh==3.0.3.
# Continuing without the dashboard.

# %%
def exec_time(code_str):
    start = time.time()
    exec(code_str, globals(), locals())
    end = time.time()
    return np.round((end-start)/60*1000, 6)

def functiontiming(cmd_d, metr_nm, dictionary, loop = 10, add_cmd = None):
    print(metr_nm)
    for key, cmd in cmd_d.items():
        counter = 0
        times = []
        try: 
            while counter <= loop:
                if add_cmd:
                    new_cmd = add_cmd[key]
                    exec_time(new_cmd)
                time = exec_time(cmd)
                times.append(time)
                counter +=1
            meant = np.round(mean(times), 6)
            stdevt = np.round(stdev(times), 6)
            maxt = np.round(max(times), 6)
            mint = np.round(min(times), 6)
            add_dic = {'METRIC': metr_nm, 'LIBRARY': key, 'TIME (avg)': meant, "TIME (stdv)": stdevt, "TIME (max)": maxt, "TIME (min)": mint,   'N': loop}

        except Exception as E:
            print(key, " ERROR:\n", str(E))
            add_dic = {}

        if metr_nm in dictionary:
            dictionary[metr_nm].append(add_dic)
        else: 
            dictionary[metr_nm] = [add_dic]
        try: 
            print(key, '\t', meant, 'usec')     
        except: print('No data')
        
def dict_to_df(dictionary, file_size = None):
    df = pd.DataFrame()
    for k, v in dictionary.items(): 
        df1 = pd.DataFrame(v)
        df = pd.concat([df, df1], axis = 0).reset_index(drop = True)
    if file_size: 
        df.loc[:,'FILE_SZ'] = file_size
    return df

# %% [markdown]
# ______
# ### ~SMALL FILE

# %%
# Number of data points to calculate statictics 
loops = 5
file = 'data/data_small.csv'
savedir = 'data_save'
savefile = f'{savedir}/results.csv'
print("File size: ", np.round(os.stat(file).st_size / (1024 * 1024), 2), "MB")
RESULT_SM = {}
# Out:
# File size:  28.92 MB

# %%
cmdsrd = {
        'datatable': 'global dtdf ; dtdf = dt.fread(file)',
        'pandas'   : 'global pdf  ; pdf  = pd.read_csv(file, low_memory = False )',
        'polars'   : 'global pldf ; pldf = pl.read_csv(file, infer_schema_length=100000, ignore_errors = True )',
        'modin'    : 'global mdf  ; mdf  = md.read_csv(file, low_memory = False)',
        'vaex'     : 'global vxdf ; vxdf = vx.open(file)'
        }
metric = 'READ_CSV'
functiontiming(cmdsrd, metric, RESULT_SM, loop = loops)
# Out:
# READ_CSV
# datatable 	 3.035216 usec
# pandas 	 24.434756 usec
# polars 	 15.01593 usec
# modin 	 39.136839 usec
# vaex 	 10.614662 usec

# %%
import os
import shutil
os.mkdir(savedir)
sv_cmd = {'datatable':'dtdf.to_csv(savefile)', 
          'pandas'   : 'pdf.to_csv(savefile)',
          'polars'   : 'pldf.write_csv(savefile)',
          'modin'    : 'mdf.to_csv(savefile)',
          'vaex'     : 'vxdf.export_csv(savefile)'
          }
metric = 'SAVE_CSV'
functiontiming(sv_cmd, metric, RESULT_SM, loop = loops)
shutil.rmtree(savedir)
# Out:
# SAVE_CSV
# datatable 	 0.755667 usec
# pandas 	 72.207063 usec
# polars 	 1.477848 usec
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# Please refer to https://modin.readthedocs.io/en/stable/supported_apis/defaulting_to_pandas.html for explanation.
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# modin 	 87.162622 usec
# vaex 	 589.779839 usec

# %%
cmdshp = {
        'datatable': 'dtdf.shape',
        'pandas'   : 'pdf.shape',
        'polars'   : 'pldf.shape',
        'modin'    : 'mdf.shape',
        'vaex'     : 'vxdf.shape'
        }
metric = 'PRINT DF SHAPE'

functiontiming(cmdshp, metric, RESULT_SM, loop = loops)
# Out:
# PRINT DF SHAPE
# datatable 	 0.000646 usec
# pandas 	 0.000948 usec
# polars 	 0.001011 usec
# modin 	 0.000872 usec
# vaex 	 0.007251 usec

# %%
cmds_copy = {
         'datatable': 'global dtdf1 ; dtdf1 = dtdf.copy()',
         'pandas'  : 'global pdf1  ; pdf1 = pdf.copy()',
         'polars'  : 'global pldf1 ; pldf1 = pldf.clone()',
         'modin'   : 'global mdf1  ; mdf1 = mdf.copy()',
         'vaex'    : 'global vxdf1 ; vxdf1 = vxdf.copy()'
        }
metric = 'CREATE COPY'
functiontiming(cmds_copy, metric, RESULT_SM, loop = loops)
# Out:
# CREATE COPY
# datatable 	 0.001038 usec
# pandas 	 0.882103 usec
# polars 	 0.001458 usec
# modin 	 0.003911 usec
# vaex 	 0.083299 usec

# %%
cmds_col1 = {
         'datatable': 'global dtdf1 ; dtdf1.names = {"CRASH_CRN":"CRASH_CRNnew"}',
         'pandas'   : 'global pdf1  ; pdf1 = pdf1.rename(columns = {"CRASH_CRN":"CRASH_CRNnew"})',
         'polars'   : 'global pldf1 ; pldf1 = pldf1.rename({"CRASH_CRN":"CRASH_CRNnew"})',
         'modin'    : 'global mdf1  ; mdf1 = mdf1.rename(columns = {"CRASH_CRN":"CRASH_CRNnew"})',
         'vaex'     :  'vxdf1.rename("CRASH_CRN","CRASH_CRNnew")'
        }
metric = 'RENAME SINGLE COLUMN'
functiontiming(cmds_col1, metric, RESULT_SM, add_cmd = cmds_copy, loop = loops)
# Out:
# RENAME SINGLE COLUMN
# datatable 	 0.002767 usec
# pandas 	 0.551608 usec
# polars 	 0.003238 usec
# modin 	 0.079664 usec
# vaex 	 0.080635 usec

# %%
new_columns = [col+'NEW' for col in pdf.columns]
new_colums_dict = {}
for col in pdf.columns:
    new_colums_dict[col] = col+'NEW'

cmds_col_all = {
         'datatable': 'global dtdf  ; dtdf.names = new_columns',
         'pandas'   : 'global pdf   ; pdf.columns = new_columns',
         # For polars to work with no errors I had to create a new dataframe. 
         # Tests without new copy in other platforms worked with no issues
         'polars'   : 'global pldf2 ; pldf2 =  pldf.rename(new_colums_dict)',
         'modin'    : 'global mdf   ; mdf = mdf.rename(columns = new_colums_dict)',
         'vaex'     : 'for cur_nm, new_nm in new_colums_dict.items(): vxdf1.rename(cur_nm, new_nm)'
        }
metric = 'RENAME ALL COLUMNS'
functiontiming(cmds_col_all, metric, RESULT_SM, add_cmd = cmds_copy, loop = loops)
# Out:
# RENAME ALL COLUMNS
# datatable 	 0.001145 usec
# pandas 	 0.008557 usec
# polars 	 0.116541 usec
# modin 	 0.085851 usec
# vaex 	 7.50989 usec

# %%
cmds_sort1 = {
         'datatable': 'dtdf[:,:, dt.sort("MUNICIPALITYNEW", reverse=True)]',
         'pandas'   : 'pdf.sort_values(by = ["MUNICIPALITYNEW"], ascending = [False])',
         'polars'   : 'pldf2.sort("MUNICIPALITYNEW", descending=True)',
         'modin'    : 'mdf.sort_values(by = ["MUNICIPALITYNEW"], ascending = [False])',
         'vaex'     : 'vxdf.sort(["MUNICIPALITY"])'
        }
metric = 'SORT ONE COLUMN'
functiontiming(cmds_sort1, metric, RESULT_SM, loop = loops)
# Out:
# SORT ONE COLUMN
# datatable 	 0.016574 usec
# pandas 	 0.985668 usec
# polars 	 0.941366 usec
# modin 	 20.306613 usec
# vaex 	 3.123385 usec

# %%
cmds_sort2 = {
         'datatable': 'dtdf[:,:, dt.sort(["MUNICIPALITYNEW", "CRASH_YEARNEW"], reverse=[True, False])]',
         'pandas'   : 'pdf.sort_values(by = ["MUNICIPALITYNEW", "CRASH_YEARNEW"], ascending = [False, True])',
         'polars'   : 'pldf2.sort("MUNICIPALITYNEW", "CRASH_YEARNEW", descending=[True, False])',
         'modin'    : 'mdf.sort_values(by = ["MUNICIPALITYNEW", "CRASH_YEARNEW"], ascending = [False, True])',
         'vaex'     : 'vxdf.sort(["MUNICIPALITY", "CRASH_YEAR"], ascending = [False, True])'
        }
metric = 'SORT TWO COLUMN'
functiontiming(cmds_sort2, metric, RESULT_SM, loop = loops)
# Out:
# SORT TWO COLUMN
# datatable 	 0.094566 usec
# pandas 	 1.097786 usec
# polars 	 0.506325 usec
# modin 	 22.750834 usec
# vaex 	 9.663084 usec

# %%
from datatable import dt, f, by
grp_by_sum = {
         'datatable': 'dtdf[:, dt.sum(f.CRASH_YEARNEW), by("MUNICIPALITYNEW")]',
         'pandas'   : 'pdf.groupby("MUNICIPALITYNEW")["CRASH_YEARNEW"].sum()',
         'polars'   : 'pldf2.group_by("MUNICIPALITYNEW").agg(pl.sum("CRASH_YEARNEW"))',
         'modin'    : 'mdf.groupby("MUNICIPALITYNEW")["CRASH_YEARNEW"].sum()',
         'vaex'     : "vxdf.groupby(by='MUNICIPALITY').agg({'CRASH_YEAR': 'sum'})"

        }
metric = 'GROUP BY SUM'
functiontiming(grp_by_sum, metric, RESULT_SM, loop = loops)
# Out:
# GROUP BY SUM
# datatable 	 0.031222 usec
# pandas 	 0.052454 usec
# polars 	 0.264512 usec
# modin 	 5.398148 usec
# vaex 	 11.199118 usec

# %%
dict_to_df(RESULT_SM, 'Small')
# Out:
#                   METRIC    LIBRARY  TIME (avg)  TIME (stdv)  TIME (max)  \
# 0               READ_CSV  datatable    3.035216     0.299732    3.643596
# 1               READ_CSV     pandas   24.434756     1.074185   26.052217
# 2               READ_CSV     polars   15.015930     0.735311   16.394500
# 3               READ_CSV      modin   39.136839    69.201014  180.380921
# 4               READ_CSV       vaex   10.614662    16.490612   44.273218
# 5               SAVE_CSV  datatable    0.755667     0.077037    0.822155
# 6               SAVE_CSV     pandas   72.207063     1.256040   74.460284
# 7               SAVE_CSV     polars    1.477848     0.302432    1.885299
# 8               SAVE_CSV      modin   87.162622     4.890749   93.962518
# 9               SAVE_CSV       vaex  589.779839    31.474616  625.821904
# 10        PRINT DF SHAPE  datatable    0.000646     0.000203    0.001049
# 11        PRINT DF SHAPE     pandas    0.000948     0.000275    0.001268
# 12        PRINT DF SHAPE     polars    0.001011     0.000821    0.002515
# 13        PRINT DF SHAPE      modin    0.000872     0.000647    0.002082
# 14        PRINT DF SHAPE       vaex    0.007251     0.014919    0.037698
# 15           CREATE COPY  datatable    0.001038     0.000565    0.002102
# 16           CREATE COPY     pandas    0.882103     0.598768    1.902648
# 17           CREATE COPY     polars    0.001458     0.000875    0.002698
# 18           CREATE COPY      modin    0.003911     0.001060    0.005964
# 19           CREATE COPY       vaex    0.083299     0.013886    0.106033
# 20  RENAME SINGLE COLUMN  datatable    0.002767     0.000646    0.003751
# 21  RENAME SINGLE COLUMN     pandas    0.551608     0.079005    0.632318
# 22  RENAME SINGLE COLUMN     polars    0.003238     0.003186    0.009716
# 23  RENAME SINGLE COLUMN      modin    0.079664     0.028812    0.135903
# 24  RENAME SINGLE COLUMN       vaex    0.080635     0.018668    0.114457
# 25    RENAME ALL COLUMNS  datatable    0.001145     0.000269    0.001685
# 26    RENAME ALL COLUMNS     pandas    0.008557     0.003593    0.015382
# 27    RENAME ALL COLUMNS     polars    0.116541     0.128997    0.375219
# 28    RENAME ALL COLUMNS      modin    0.085851     0.044590    0.175619
# 29    RENAME ALL COLUMNS       vaex    7.509890     1.906168   10.021484
# 30       SORT ONE COLUMN  datatable    0.016574     0.005890    0.026929
# 31       SORT ONE COLUMN     pandas    0.985668     0.377814    1.748665
# 32       SORT ONE COLUMN     polars    0.941366     0.713488    2.391128
# 33       SORT ONE COLUMN      modin   20.306613     5.138580   29.876415
# 34       SORT ONE COLUMN       vaex    3.123385     0.519726    4.038048
# 35       SORT TWO COLUMN  datatable    0.094566     0.010492    0.113885
# 36       SORT TWO COLUMN     pandas    1.097786     0.430950    1.925317
# 37       SORT TWO COLUMN     polars    0.506325     0.046754    0.558515
# 38       SORT TWO COLUMN      modin   22.750834     5.089133   28.792067
# 39       SORT TWO COLUMN       vaex    9.663084     2.573231   14.358497
# 40          GROUP BY SUM  datatable    0.031222     0.021790    0.075018
# 41          GROUP BY SUM     pandas    0.052454     0.058228    0.170986
# 42          GROUP BY SUM     polars    0.264512     0.069708    0.374269
# 43          GROUP BY SUM      modin    5.398148     1.799851    8.519284
# 44          GROUP BY SUM       vaex   11.199118     1.137899   12.830802
#
#     TIME (min)  N FILE_SZ
# 0     2.867917  5   Small
# 1    23.342713  5   Small
# 2    14.467748  5   Small
# 3     9.727482  5   Small
# 4     3.640886  5   Small
# 5     0.620766  5   Small
# 6    70.638533  5   Small
# 7     1.229318  5   Small
# 8    81.726201  5   Small
# 9   551.037749  5   Small
# 10    0.000532  5   Small
# 11    0.000652  5   Small
# 12    0.000366  5   Small
# 13    0.000437  5   Small
# 14    0.000950  5   Small
# 15    0.000536  5   Small
# 16    0.447436  5   Small
# 17    0.000612  5   Small
# 18    0.003246  5   Small
# 19    0.066853  5   Small
# 20    0.002015  5   Small
# 21    0.437967  5   Small
# 22    0.001748  5   Small
# 23    0.058766  5   Small
# 24    0.064651  5   Small
# 25    0.000985  5   Small
# 26    0.005635  5   Small
# 27    0.026103  5   Small
# 28    0.055989  5   Small
# 29    5.579754  5   Small
# 30    0.011996  5   Small
# 31    0.746036  5   Small
# 32    0.559616  5   Small
# 33   15.447203  5   Small
# 34    2.485832  5   Small
# 35    0.084964  5   Small
# 36    0.760682  5   Small
# 37    0.445648  5   Small
# 38   17.219583  5   Small
# 39    6.700683  5   Small
# 40    0.019467  5   Small
# 41    0.023806  5   Small
# 42    0.191081  5   Small
# 43    3.729002  5   Small
# 44    9.627851  5   Small

# %% [markdown]
# _____
#
# ### ~Medium file

# %%
### Deleting dataframes used with the Small file data
del dtdf, dtdf1, pdf, pdf1, pldf, pldf1, pldf2, mdf, mdf1, vxdf, vxdf1

# %%
file = 'data/data_medium.csv'
print("File size: ", np.round(os.stat(file).st_size / (1024 * 1024), 2), "MB")
RESULT_MD = {}
# Out:
# File size:  145.88 MB

# %%
metric = 'READ_CSV'
functiontiming(cmdsrd, metric, RESULT_MD, loop = loops)
os.mkdir(savedir)
metric = 'SAVE_CSV'
functiontiming(sv_cmd, metric, RESULT_MD, loop = loops)
shutil.rmtree(savedir)
metric = 'PRINT DF SHAPE'
functiontiming(cmdshp, metric, RESULT_MD, loop = loops)
metric = 'CREATE COPY'
functiontiming(cmds_copy, metric, RESULT_MD, loop = loops)
metric = 'RENAME SINGLE COLUMN'
functiontiming(cmds_col1, metric, RESULT_MD, add_cmd = cmds_copy, loop = loops)
metric = 'RENAME ALL COLUMNS'
functiontiming(cmds_col_all, metric, RESULT_MD, add_cmd = cmds_copy, loop = loops)
metric = 'SORT ONE COLUMN'
functiontiming(cmds_sort1, metric, RESULT_MD, loop = loops)
metric = 'SORT TWO COLUMN'
functiontiming(cmds_sort2, metric, RESULT_MD, loop = loops)
metric = 'GROUP BY SUM'
functiontiming(grp_by_sum, metric, RESULT_MD, loop = loops)
# Out:
# READ_CSV
# datatable 	 8.783688 usec
# pandas 	 135.03677 usec
# polars 	 36.944571 usec
# UserWarning: `read_*` implementation has mismatches with pandas:
# Data types of partitions are different! Please refer to the troubleshooting section of the Modin documentation to fix this issue.
# modin 	 52.669373 usec
# vaex 	 5.091153 usec
# SAVE_CSV
# datatable 	 4.106835 usec
# pandas 	 401.249525 usec
# polars 	 5.604123 usec
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# modin 	 417.528212 usec
# vaex  ERROR:
#  Error reading csv file data/data_medium.csv, write offending chunk to: /var/folders/dg/fckc2gz96c599j8pqfzz6jzr0000gn/T/tmpdf8tvilx.csv (len=10486076, first=False, columns=['SCHOOL_BUS_UNIT'], schema=SCHOOL_BUS_UNIT: int8, encoding=utf8, schema_infer_fraction=0.001).
# Possible causes:
#   * This could be a file encoding error. Consider passing read_options=pyarrow.csv.ReadOptions(encoding="ISO-8859-1") or another encoding as argument.
#   * We might have inferred the wrong schema:
#      * Consider giving a schema hint by e.g. passing read_options=pyarrow.csv.ConvertOptions(column_types={"SomeId": pyarrow.string()}).
#      * Consider increasing schema_infer_fraction (e.g. schema_infer_fraction=1 to parse the whole file to infer the schema).
#
# vaex 	 417.528212 usec
# PRINT DF SHAPE
# datatable 	 0.00042 usec
# pandas 	 0.000476 usec
# polars 	 0.000414 usec
# modin 	 0.000591 usec
# vaex 	 0.001053 usec
# CREATE COPY
# datatable 	 0.000756 usec
# pandas 	 4.568166 usec
# polars 	 0.000803 usec
# modin 	 0.003764 usec
# vaex 	 0.06087 usec
# RENAME SINGLE COLUMN
# datatable 	 0.001352 usec
# pandas 	 4.260151 usec
# polars 	 0.002446 usec
# modin 	 0.055729 usec
# vaex 	 0.067964 usec
# RENAME ALL COLUMNS
# datatable 	 0.00122 usec
# pandas 	 0.007119 usec
# polars 	 0.018431 usec
# modin 	 0.057848 usec
# vaex 	 4.508646 usec
# SORT ONE COLUMN
# datatable 	 0.024052 usec
# pandas 	 5.945763 usec
# polars 	 4.404716 usec
# modin 	 46.679827 usec
# vaex 	 9.859324 usec
# SORT TWO COLUMN
# datatable 	 0.16806 usec
# pandas 	 6.540375 usec
# polars 	 3.219565 usec
# modin 	 44.157058 usec
# vaex 	 20.487904 usec
# GROUP BY SUM
# datatable 	 0.083376 usec
# pandas 	 0.083094 usec
# polars 	 0.880671 usec
# modin 	 4.166701 usec
# vaex 	 23.22429 usec

# %%
dict_to_df(RESULT_MD, 'Medium')
# Out:
#                   METRIC    LIBRARY  TIME (avg)  TIME (stdv)  TIME (max)  \
# 0               READ_CSV  datatable    8.783688     1.510068   11.329150
# 1               READ_CSV     pandas  135.036770     5.965601  145.370869
# 2               READ_CSV     polars   36.944571     1.834819   39.421447
# 3               READ_CSV      modin   52.669373     7.963601   68.519553
# 4               READ_CSV       vaex    5.091153     0.718483    6.291298
# 5               SAVE_CSV  datatable    4.106835     0.485024    4.628531
# 6               SAVE_CSV     pandas  401.249525    12.673637  421.955403
# 7               SAVE_CSV     polars    5.604123     0.315362    6.213439
# 8               SAVE_CSV      modin  417.528212     8.801548  430.928151
# 9                    NaN        NaN         NaN          NaN         NaN
# 10        PRINT DF SHAPE  datatable    0.000420     0.000144    0.000703
# 11        PRINT DF SHAPE     pandas    0.000476     0.000243    0.000966
# 12        PRINT DF SHAPE     polars    0.000414     0.000134    0.000683
# 13        PRINT DF SHAPE      modin    0.000591     0.000231    0.001049
# 14        PRINT DF SHAPE       vaex    0.001053     0.000183    0.001419
# 15           CREATE COPY  datatable    0.000756     0.000412    0.001585
# 16           CREATE COPY     pandas    4.568166     0.966018    6.403665
# 17           CREATE COPY     polars    0.000803     0.000449    0.001701
# 18           CREATE COPY      modin    0.003764     0.000991    0.005770
# 19           CREATE COPY       vaex    0.060870     0.009245    0.079580
# 20  RENAME SINGLE COLUMN  datatable    0.001352     0.000256    0.001713
# 21  RENAME SINGLE COLUMN     pandas    4.260151     0.052809    4.334633
# 22  RENAME SINGLE COLUMN     polars    0.002446     0.001468    0.005436
# 23  RENAME SINGLE COLUMN      modin    0.055729     0.002782    0.060503
# 24  RENAME SINGLE COLUMN       vaex    0.067964     0.007840    0.081348
# 25    RENAME ALL COLUMNS  datatable    0.001220     0.000278    0.001585
# 26    RENAME ALL COLUMNS     pandas    0.007119     0.003071    0.013300
# 27    RENAME ALL COLUMNS     polars    0.018431     0.008376    0.030156
# 28    RENAME ALL COLUMNS      modin    0.057848     0.002730    0.061822
# 29    RENAME ALL COLUMNS       vaex    4.508646     0.146020    4.679982
# 30       SORT ONE COLUMN  datatable    0.024052     0.014581    0.053569
# 31       SORT ONE COLUMN     pandas    5.945763     0.074765    6.084617
# 32       SORT ONE COLUMN     polars    4.404716     2.794410   10.031835
# 33       SORT ONE COLUMN      modin   46.679827     7.297546   59.914184
# 34       SORT ONE COLUMN       vaex    9.859324     1.280579   12.364352
# 35       SORT TWO COLUMN  datatable    0.168060     0.010183    0.187182
# 36       SORT TWO COLUMN     pandas    6.540375     0.572948    7.413332
# 37       SORT TWO COLUMN     polars    3.219565     0.107332    3.383251
# 38       SORT TWO COLUMN      modin   44.157058     4.937268   51.466215
# 39       SORT TWO COLUMN       vaex   20.487904     2.168136   24.648070
# 40          GROUP BY SUM  datatable    0.083376     0.031991    0.145034
# 41          GROUP BY SUM     pandas    0.083094     0.014550    0.111588
# 42          GROUP BY SUM     polars    0.880671     0.066653    0.960048
# 43          GROUP BY SUM      modin    4.166701     0.316641    4.671403
# 44          GROUP BY SUM       vaex   23.224290     0.564609   23.834038
#
#     TIME (min)    N FILE_SZ
# 0     7.649851  5.0  Medium
# 1   129.675917  5.0  Medium
# 2    34.929768  5.0  Medium
# 3    46.940299  5.0  Medium
# 4     4.233817  5.0  Medium
# 5     3.603880  5.0  Medium
# 6   388.322131  5.0  Medium
# 7     5.369985  5.0  Medium
# 8   407.915469  5.0  Medium
# 9          NaN  NaN  Medium
# 10    0.000330  5.0  Medium
# 11    0.000350  5.0  Medium
# 12    0.000334  5.0  Medium
# 13    0.000445  5.0  Medium
# 14    0.000946  5.0  Medium
# 15    0.000536  5.0  Medium
# 16    3.938679  5.0  Medium
# 17    0.000548  5.0  Medium
# 18    0.003235  5.0  Medium
# 19    0.055484  5.0  Medium
# 20    0.001113  5.0  Medium
# 21    4.182748  5.0  Medium
# 22    0.001705  5.0  Medium
# 23    0.052985  5.0  Medium
# 24    0.061834  5.0  Medium
# 25    0.000997  5.0  Medium
# 26    0.005448  5.0  Medium
# 27    0.011647  5.0  Medium
# 28    0.054534  5.0  Medium
# 29    4.294666  5.0  Medium
# 30    0.016812  5.0  Medium
# 31    5.864167  5.0  Medium
# 32    2.856533  5.0  Medium
# 33   40.274882  5.0  Medium
# 34    8.845564  5.0  Medium
# 35    0.159617  5.0  Medium
# 36    6.078768  5.0  Medium
# 37    3.082315  5.0  Medium
# 38   38.732433  5.0  Medium
# 39   18.308918  5.0  Medium
# 40    0.058997  5.0  Medium
# 41    0.074430  5.0  Medium
# 42    0.791939  5.0  Medium
# 43    3.702637  5.0  Medium
# 44   22.281265  5.0  Medium

# %% [markdown]
# _____
#
# ### ~Large file

# %%
### Deleting dataframes used with the Medium file data
del dtdf, dtdf1, pdf, pdf1, pldf, pldf1, pldf2, mdf, mdf1, vxdf, vxdf1

# %%
file = 'data/data_large.csv'
print("File size: ", np.round(os.stat(file).st_size / (1024 * 1024), 2), "MB")
RESULT_LG = {}
# Out:
# File size:  291.77 MB

# %%
metric = 'READ_CSV'
functiontiming(cmdsrd, metric, RESULT_LG, loop = loops)
metric = 'SAVE_CSV'
os.mkdir(savedir)
functiontiming(sv_cmd, metric, RESULT_LG, loop = loops)
shutil.rmtree(savedir)
metric = 'PRINT DF SHAPE'
functiontiming(cmdshp, metric, RESULT_LG, loop = loops)
metric = 'CREATE COPY'
functiontiming(cmds_copy, metric, RESULT_LG, loop = loops)
metric = 'RENAME SINGLE COLUMN'
functiontiming(cmds_col1, metric, RESULT_LG, add_cmd = cmds_copy, loop = loops)
metric = 'RENAME ALL COLUMNS'
functiontiming(cmds_col_all, metric, RESULT_LG, add_cmd = cmds_copy, loop = loops)
metric = 'SORT ONE COLUMN'
functiontiming(cmds_sort1, metric, RESULT_LG, loop = loops)
metric = 'SORT TWO COLUMN'
functiontiming(cmds_sort2, metric, RESULT_LG, loop = loops)
metric = 'GROUP BY SUM'
functiontiming(grp_by_sum, metric, RESULT_LG, loop = loops)
# Out:
# READ_CSV
# datatable 	 13.394466 usec
# pandas 	 281.879768 usec
# polars 	 42.350862 usec
# modin 	 96.130862 usec
# vaex 	 5.659048 usec
# SAVE_CSV
# datatable 	 7.53634 usec
# pandas 	 797.117705 usec
# polars 	 10.297295 usec
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: `to_csv` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# modin 	 954.855666 usec
# vaex  ERROR:
#  Error reading csv file data/data_large.csv, write offending chunk to: /var/folders/dg/fckc2gz96c599j8pqfzz6jzr0000gn/T/tmp434an9ut.csv (len=10486076, first=False, columns=['SCHOOL_BUS_UNIT'], schema=SCHOOL_BUS_UNIT: int8, encoding=utf8, schema_infer_fraction=0.001).
# Possible causes:
#   * This could be a file encoding error. Consider passing read_options=pyarrow.csv.ReadOptions(encoding="ISO-8859-1") or another encoding as argument.
#   * We might have inferred the wrong schema:
#      * Consider giving a schema hint by e.g. passing read_options=pyarrow.csv.ConvertOptions(column_types={"SomeId": pyarrow.string()}).
#      * Consider increasing schema_infer_fraction (e.g. schema_infer_fraction=1 to parse the whole file to infer the schema).
#
# vaex 	 954.855666 usec
# PRINT DF SHAPE
# datatable 	 0.001586 usec
# pandas 	 0.001714 usec
# polars 	 0.00235 usec
# modin 	 0.002615 usec
# vaex 	 0.004505 usec
# CREATE COPY
# datatable 	 0.003913 usec
# pandas 	 37.788526 usec
# polars 	 0.003618 usec
# modin 	 0.022063 usec
# vaex 	 0.244611 usec
# RENAME SINGLE COLUMN
# datatable 	 0.005702 usec
# pandas 	 30.848218 usec
# polars 	 0.039993 usec
# modin 	 0.200352 usec
# vaex 	 0.256804 usec
# RENAME ALL COLUMNS
# datatable 	 0.003893 usec
# pandas 	 0.014914 usec
# polars 	 0.113292 usec
# modin 	 0.227296 usec
# vaex 	 15.588737 usec
# SORT ONE COLUMN
# datatable 	 0.17152 usec
# pandas 	 40.066639 usec
# polars 	 31.439814 usec
# modin 	 252.647242 usec
# vaex 	 61.051636 usec
# SORT TWO COLUMN
# datatable 	 0.910065 usec
# pandas 	 49.305056 usec
# polars 	 11.506968 usec
# modin 	 223.143358 usec
# vaex 	 114.943753 usec
# GROUP BY SUM
# datatable 	 0.41597 usec
# pandas 	 0.48896 usec
# polars 	 3.724246 usec
# modin 	 12.670636 usec
# vaex 	 123.370393 usec

# %%
dict_to_df(RESULT_LG, 'Large')
# Out:
#                   METRIC    LIBRARY  TIME (avg)  TIME (stdv)   TIME (max)  \
# 0               READ_CSV  datatable   12.171684     1.301270    14.444264
# 1               READ_CSV     pandas  265.569262     7.201429   273.324247
# 2               READ_CSV     polars   40.089969     1.990265    43.246766
# 3               READ_CSV      modin   95.542750    10.143313   108.659705
# 4               READ_CSV       vaex    4.328803     0.304770     4.815149
# 5               READ_CSV  datatable   13.394466     1.141478    14.693252
# 6               READ_CSV     pandas  281.879768    25.783281   329.836551
# 7               READ_CSV     polars   42.350862     2.545283    46.006715
# 8               READ_CSV      modin   96.130862     8.221473   106.081339
# 9               READ_CSV       vaex    5.659048     2.228114    10.158761
# 10                   NaN        NaN         NaN          NaN          NaN
# 11                   NaN        NaN         NaN          NaN          NaN
# 12                   NaN        NaN         NaN          NaN          NaN
# 13                   NaN        NaN         NaN          NaN          NaN
# 14                   NaN        NaN         NaN          NaN          NaN
# 15              SAVE_CSV  datatable    7.536340     0.831893     9.202464
# 16              SAVE_CSV     pandas  797.117705    16.980403   829.591417
# 17              SAVE_CSV     polars   10.297295     1.002824    11.903151
# 18              SAVE_CSV      modin  954.855666   110.671332  1170.125902
# 19                   NaN        NaN         NaN          NaN          NaN
# 20        PRINT DF SHAPE  datatable    0.001586     0.001105     0.003819
# 21        PRINT DF SHAPE     pandas    0.001714     0.001158     0.004049
# 22        PRINT DF SHAPE     polars    0.002350     0.002885     0.008233
# 23        PRINT DF SHAPE      modin    0.002615     0.000948     0.003763
# 24        PRINT DF SHAPE       vaex    0.004505     0.002068     0.008516
# 25           CREATE COPY  datatable    0.003913     0.004746     0.013582
# 26           CREATE COPY     pandas   37.788526    18.369982    74.993018
# 27           CREATE COPY     polars    0.003618     0.004048     0.011849
# 28           CREATE COPY      modin    0.022063     0.027136     0.077415
# 29           CREATE COPY       vaex    0.244611     0.055765     0.306300
# 30  RENAME SINGLE COLUMN  datatable    0.005702     0.004293     0.014452
# 31  RENAME SINGLE COLUMN     pandas   30.848218     0.651650    31.838636
# 32  RENAME SINGLE COLUMN     polars    0.039993     0.058407     0.158250
# 33  RENAME SINGLE COLUMN      modin    0.200352     0.049733     0.300133
# 34  RENAME SINGLE COLUMN       vaex    0.256804     0.045734     0.347197
# 35    RENAME ALL COLUMNS  datatable    0.003893     0.000964     0.005770
# 36    RENAME ALL COLUMNS     pandas    0.014914     0.000429     0.015434
# 37    RENAME ALL COLUMNS     polars    0.113292     0.075735     0.233003
# 38    RENAME ALL COLUMNS      modin    0.227296     0.051237     0.327849
# 39    RENAME ALL COLUMNS       vaex   15.588737     0.645761    16.513618
# 40       SORT ONE COLUMN  datatable    0.171520     0.248254     0.678051
# 41       SORT ONE COLUMN     pandas   40.066639     1.164905    41.305085
# 42       SORT ONE COLUMN     polars   31.439814    42.445011   116.946618
# 43       SORT ONE COLUMN      modin  252.647242    75.811429   406.314150
# 44       SORT ONE COLUMN       vaex   61.051636    10.696210    81.995237
# 45       SORT TWO COLUMN  datatable    0.910065     0.321489     1.544333
# 46       SORT TWO COLUMN     pandas   49.305056    21.270010    92.669054
# 47       SORT TWO COLUMN     polars   11.506968     2.380920    16.342783
# 48       SORT TWO COLUMN      modin  223.143358    38.408357   275.166770
# 49       SORT TWO COLUMN       vaex  114.943753    13.129963   139.659270
# 50          GROUP BY SUM  datatable    0.415970     0.064551     0.507402
# 51          GROUP BY SUM     pandas    0.488960     0.086043     0.663586
# 52          GROUP BY SUM     polars    3.724246     0.798933     5.181019
# 53          GROUP BY SUM      modin   12.670636     0.640763    13.748769
# 54          GROUP BY SUM       vaex  123.370393     5.478938   132.015133
#
#     TIME (min)    N FILE_SZ
# 0    10.978353  5.0   Large
# 1   255.090968  5.0   Large
# 2    38.256216  5.0   Large
# 3    86.025929  5.0   Large
# 4     4.048900  5.0   Large
# 5    11.961110  5.0   Large
# 6   260.798252  5.0   Large
# 7    39.403303  5.0   Large
# 8    87.602317  5.0   Large
# 9     4.383767  5.0   Large
# 10         NaN  NaN   Large
# 11         NaN  NaN   Large
# 12         NaN  NaN   Large
# 13         NaN  NaN   Large
# 14         NaN  NaN   Large
# 15    7.030845  5.0   Large
# 16  780.361533  5.0   Large
# 17    9.062095  5.0   Large
# 18  881.338497  5.0   Large
# 19         NaN  NaN   Large
# 20    0.001029  5.0   Large
# 21    0.001097  5.0   Large
# 22    0.001085  5.0   Large
# 23    0.001597  5.0   Large
# 24    0.003167  5.0   Large
# 25    0.001752  5.0   Large
# 26   28.612669  5.0   Large
# 27    0.001681  5.0   Large
# 28    0.010204  5.0   Large
# 29    0.190830  5.0   Large
# 30    0.003684  5.0   Large
# 31   30.341236  5.0   Large
# 32    0.006314  5.0   Large
# 33    0.170064  5.0   Large
# 34    0.224864  5.0   Large
# 35    0.003286  5.0   Large
# 36    0.014166  5.0   Large
# 37    0.042001  5.0   Large
# 38    0.189932  5.0   Large
# 39   14.605085  5.0   Large
# 40    0.064147  5.0   Large
# 41   38.899628  5.0   Large
# 42   10.114900  5.0   Large
# 43  211.562534  5.0   Large
# 44   53.818985  5.0   Large
# 45    0.662704  5.0   Large
# 46   39.437850  5.0   Large
# 47   10.221469  5.0   Large
# 48  180.819082  5.0   Large
# 49  105.125582  5.0   Large
# 50    0.348349  5.0   Large
# 51    0.443927  5.0   Large
# 52    3.093266  5.0   Large
# 53   12.150335  5.0   Large
# 54  117.928469  5.0   Large

# %%
client.close()

# %% [markdown]
# ____
#
# # Combining the results

# %%
results = dict_to_df(RESULT_LG).drop(['N'], axis = 1).merge(dict_to_df(RESULT_MD), on = ['METRIC', 'LIBRARY'], suffixes=['_LG', '_MD']).drop(['N'], axis = 1).merge(dict_to_df(RESULT_SM), on = ['METRIC', 'LIBRARY'])
ordered_columns = ['METRIC', 'LIBRARY', 'TIME (avg)_LG', 'TIME (avg)_MD', 'TIME (avg)',
                    'TIME (stdv)_LG', 'TIME (stdv)_MD', 'TIME (stdv)', 
                    'TIME (max)_LG', 'TIME (max)_MD', 'TIME (max)',
                    'TIME (min)_LG', 'TIME (min)_MD', 'TIME (min)', 'N']
results[ordered_columns]
# Out:
#                   METRIC    LIBRARY  TIME (avg)_LG  TIME (avg)_MD  TIME (avg)  \
# 0               READ_CSV  datatable      12.171684       8.783688    3.035216
# 1               READ_CSV  datatable      13.394466       8.783688    3.035216
# 2               READ_CSV     pandas     265.569262     135.036770   24.434756
# 3               READ_CSV     pandas     281.879768     135.036770   24.434756
# 4               READ_CSV     polars      40.089969      36.944571   15.015930
# 5               READ_CSV     polars      42.350862      36.944571   15.015930
# 6               READ_CSV      modin      95.542750      52.669373   39.136839
# 7               READ_CSV      modin      96.130862      52.669373   39.136839
# 8               READ_CSV       vaex       4.328803       5.091153   10.614662
# 9               READ_CSV       vaex       5.659048       5.091153   10.614662
# 10              SAVE_CSV  datatable       7.536340       4.106835    0.755667
# 11              SAVE_CSV     pandas     797.117705     401.249525   72.207063
# 12              SAVE_CSV     polars      10.297295       5.604123    1.477848
# 13              SAVE_CSV      modin     954.855666     417.528212   87.162622
# 14        PRINT DF SHAPE  datatable       0.001586       0.000420    0.000646
# 15        PRINT DF SHAPE     pandas       0.001714       0.000476    0.000948
# 16        PRINT DF SHAPE     polars       0.002350       0.000414    0.001011
# 17        PRINT DF SHAPE      modin       0.002615       0.000591    0.000872
# 18        PRINT DF SHAPE       vaex       0.004505       0.001053    0.007251
# 19           CREATE COPY  datatable       0.003913       0.000756    0.001038
# 20           CREATE COPY     pandas      37.788526       4.568166    0.882103
# 21           CREATE COPY     polars       0.003618       0.000803    0.001458
# 22           CREATE COPY      modin       0.022063       0.003764    0.003911
# 23           CREATE COPY       vaex       0.244611       0.060870    0.083299
# 24  RENAME SINGLE COLUMN  datatable       0.005702       0.001352    0.002767
# 25  RENAME SINGLE COLUMN     pandas      30.848218       4.260151    0.551608
# 26  RENAME SINGLE COLUMN     polars       0.039993       0.002446    0.003238
# 27  RENAME SINGLE COLUMN      modin       0.200352       0.055729    0.079664
# 28  RENAME SINGLE COLUMN       vaex       0.256804       0.067964    0.080635
# 29    RENAME ALL COLUMNS  datatable       0.003893       0.001220    0.001145
# 30    RENAME ALL COLUMNS     pandas       0.014914       0.007119    0.008557
# 31    RENAME ALL COLUMNS     polars       0.113292       0.018431    0.116541
# 32    RENAME ALL COLUMNS      modin       0.227296       0.057848    0.085851
# 33    RENAME ALL COLUMNS       vaex      15.588737       4.508646    7.509890
# 34       SORT ONE COLUMN  datatable       0.171520       0.024052    0.016574
# 35       SORT ONE COLUMN     pandas      40.066639       5.945763    0.985668
# 36       SORT ONE COLUMN     polars      31.439814       4.404716    0.941366
# 37       SORT ONE COLUMN      modin     252.647242      46.679827   20.306613
# 38       SORT ONE COLUMN       vaex      61.051636       9.859324    3.123385
# 39       SORT TWO COLUMN  datatable       0.910065       0.168060    0.094566
# 40       SORT TWO COLUMN     pandas      49.305056       6.540375    1.097786
# 41       SORT TWO COLUMN     polars      11.506968       3.219565    0.506325
# 42       SORT TWO COLUMN      modin     223.143358      44.157058   22.750834
# 43       SORT TWO COLUMN       vaex     114.943753      20.487904    9.663084
# 44          GROUP BY SUM  datatable       0.415970       0.083376    0.031222
# 45          GROUP BY SUM     pandas       0.488960       0.083094    0.052454
# 46          GROUP BY SUM     polars       3.724246       0.880671    0.264512
# 47          GROUP BY SUM      modin      12.670636       4.166701    5.398148
# 48          GROUP BY SUM       vaex     123.370393      23.224290   11.199118
#
#     TIME (stdv)_LG  TIME (stdv)_MD  TIME (stdv)  TIME (max)_LG  TIME (max)_MD  \
# 0         1.301270        1.510068     0.299732      14.444264      11.329150
# 1         1.141478        1.510068     0.299732      14.693252      11.329150
# 2         7.201429        5.965601     1.074185     273.324247     145.370869
# 3        25.783281        5.965601     1.074185     329.836551     145.370869
# 4         1.990265        1.834819     0.735311      43.246766      39.421447
# 5         2.545283        1.834819     0.735311      46.006715      39.421447
# 6        10.143313        7.963601    69.201014     108.659705      68.519553
# 7         8.221473        7.963601    69.201014     106.081339      68.519553
# 8         0.304770        0.718483    16.490612       4.815149       6.291298
# 9         2.228114        0.718483    16.490612      10.158761       6.291298
# 10        0.831893        0.485024     0.077037       9.202464       4.628531
# 11       16.980403       12.673637     1.256040     829.591417     421.955403
# 12        1.002824        0.315362     0.302432      11.903151       6.213439
# 13      110.671332        8.801548     4.890749    1170.125902     430.928151
# 14        0.001105        0.000144     0.000203       0.003819       0.000703
# 15        0.001158        0.000243     0.000275       0.004049       0.000966
# 16        0.002885        0.000134     0.000821       0.008233       0.000683
# 17        0.000948        0.000231     0.000647       0.003763       0.001049
# 18        0.002068        0.000183     0.014919       0.008516       0.001419
# 19        0.004746        0.000412     0.000565       0.013582       0.001585
# 20       18.369982        0.966018     0.598768      74.993018       6.403665
# 21        0.004048        0.000449     0.000875       0.011849       0.001701
# 22        0.027136        0.000991     0.001060       0.077415       0.005770
# 23        0.055765        0.009245     0.013886       0.306300       0.079580
# 24        0.004293        0.000256     0.000646       0.014452       0.001713
# 25        0.651650        0.052809     0.079005      31.838636       4.334633
# 26        0.058407        0.001468     0.003186       0.158250       0.005436
# 27        0.049733        0.002782     0.028812       0.300133       0.060503
# 28        0.045734        0.007840     0.018668       0.347197       0.081348
# 29        0.000964        0.000278     0.000269       0.005770       0.001585
# 30        0.000429        0.003071     0.003593       0.015434       0.013300
# 31        0.075735        0.008376     0.128997       0.233003       0.030156
# 32        0.051237        0.002730     0.044590       0.327849       0.061822
# 33        0.645761        0.146020     1.906168      16.513618       4.679982
# 34        0.248254        0.014581     0.005890       0.678051       0.053569
# 35        1.164905        0.074765     0.377814      41.305085       6.084617
# 36       42.445011        2.794410     0.713488     116.946618      10.031835
# 37       75.811429        7.297546     5.138580     406.314150      59.914184
# 38       10.696210        1.280579     0.519726      81.995237      12.364352
# 39        0.321489        0.010183     0.010492       1.544333       0.187182
# 40       21.270010        0.572948     0.430950      92.669054       7.413332
# 41        2.380920        0.107332     0.046754      16.342783       3.383251
# 42       38.408357        4.937268     5.089133     275.166770      51.466215
# 43       13.129963        2.168136     2.573231     139.659270      24.648070
# 44        0.064551        0.031991     0.021790       0.507402       0.145034
# 45        0.086043        0.014550     0.058228       0.663586       0.111588
# 46        0.798933        0.066653     0.069708       5.181019       0.960048
# 47        0.640763        0.316641     1.799851      13.748769       4.671403
# 48        5.478938        0.564609     1.137899     132.015133      23.834038
#
#     TIME (max)  TIME (min)_LG  TIME (min)_MD  TIME (min)  N
# 0     3.643596      10.978353       7.649851    2.867917  5
# 1     3.643596      11.961110       7.649851    2.867917  5
# 2    26.052217     255.090968     129.675917   23.342713  5
# 3    26.052217     260.798252     129.675917   23.342713  5
# 4    16.394500      38.256216      34.929768   14.467748  5
# 5    16.394500      39.403303      34.929768   14.467748  5
# 6   180.380921      86.025929      46.940299    9.727482  5
# 7   180.380921      87.602317      46.940299    9.727482  5
# 8    44.273218       4.048900       4.233817    3.640886  5
# 9    44.273218       4.383767       4.233817    3.640886  5
# 10    0.822155       7.030845       3.603880    0.620766  5
# 11   74.460284     780.361533     388.322131   70.638533  5
# 12    1.885299       9.062095       5.369985    1.229318  5
# 13   93.962518     881.338497     407.915469   81.726201  5
# 14    0.001049       0.001029       0.000330    0.000532  5
# 15    0.001268       0.001097       0.000350    0.000652  5
# 16    0.002515       0.001085       0.000334    0.000366  5
# 17    0.002082       0.001597       0.000445    0.000437  5
# 18    0.037698       0.003167       0.000946    0.000950  5
# 19    0.002102       0.001752       0.000536    0.000536  5
# 20    1.902648      28.612669       3.938679    0.447436  5
# 21    0.002698       0.001681       0.000548    0.000612  5
# 22    0.005964       0.010204       0.003235    0.003246  5
# 23    0.106033       0.190830       0.055484    0.066853  5
# 24    0.003751       0.003684       0.001113    0.002015  5
# 25    0.632318      30.341236       4.182748    0.437967  5
# 26    0.009716       0.006314       0.001705    0.001748  5
# 27    0.135903       0.170064       0.052985    0.058766  5
# 28    0.114457       0.224864       0.061834    0.064651  5
# 29    0.001685       0.003286       0.000997    0.000985  5
# 30    0.015382       0.014166       0.005448    0.005635  5
# 31    0.375219       0.042001       0.011647    0.026103  5
# 32    0.175619       0.189932       0.054534    0.055989  5
# 33   10.021484      14.605085       4.294666    5.579754  5
# 34    0.026929       0.064147       0.016812    0.011996  5
# 35    1.748665      38.899628       5.864167    0.746036  5
# 36    2.391128      10.114900       2.856533    0.559616  5
# 37   29.876415     211.562534      40.274882   15.447203  5
# 38    4.038048      53.818985       8.845564    2.485832  5
# 39    0.113885       0.662704       0.159617    0.084964  5
# 40    1.925317      39.437850       6.078768    0.760682  5
# 41    0.558515      10.221469       3.082315    0.445648  5
# 42   28.792067     180.819082      38.732433   17.219583  5
# 43   14.358497     105.125582      18.308918    6.700683  5
# 44    0.075018       0.348349       0.058997    0.019467  5
# 45    0.170986       0.443927       0.074430    0.023806  5
# 46    0.374269       3.093266       0.791939    0.191081  5
# 47    8.519284      12.150335       3.702637    3.729002  5
# 48   12.830802     117.928469      22.281265    9.627851  5
